# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Setup and prepare

# %%
# Load the scraped studies' data and extract all DOIs from the date string
# Studies with multiple iterations have the same DOI, but end with "v2", "v3", etc.

df = pd.read_csv("./FullScraped.csv", index_col=0)
dois = [d.split("doi: ")[1].strip() if "doi: " in d else "" for d in df.date.tolist()]

# %%
#Load the generated questions and labels from the text fiel
with open("generated_questions_labels.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

questions = list()
labels = list()

for idx,line in enumerate(lines):
    #if idx in missing_indices:
    #    continue
    line = line.split("\n")[0]
    line = line.split(" ||| ")
    questions.append(line[0].split("QUESTION: ")[1].strip())
    labels.append(line[1].split("LABEL: ")[1].strip())

# %%
# Group the questions by DOI, so that multiple iterations of the same study are together in a group
doigroups = list()
indices = {}
for idx in range(len(dois)):
    d = dois[idx]
    if d not in indices:
        indices[d] = idx 

doisorted = sorted(dois)

# Iterate through the sorted DOIs and group them by common prefix. "Pivot" is the earliest study in the group.
idx = 0
while idx < len(dois):
    pivot = doisorted[idx]
    if pivot == "":
        idx += 1
        continue
    doigroup = list()
    while idx < len(dois) and doisorted[idx].startswith(pivot):
        doigroup.append(indices[doisorted[idx]])
        idx += 1
    doigroups.append(doigroup)

doigroups = [list(set(dg)) for dg in doigroups]
doigroups = sorted(doigroups)

def remove_duplicates(lst):
    seen = set()
    result = []
    for item in lst:
        if item not in seen:
            seen.add(item)
            result.append(item)
    return result

doigroups = [remove_duplicates(dg) for dg in doigroups]
doigroups = sorted(doigroups)

# %%
# Create a mapping of study iterations (by index) to their labels, for studies with multiple iterations
long_doigroups = list()
long_indices = list()
for idx,dg in enumerate(doigroups):
    if len(dg) > 1:
        long_doigroups.append(dg)
        long_indices.append(idx)

verdict_map = list()
for ld in long_doigroups:
    instance_verdicts = {}
    sorted_ld = sorted(ld)
    for idx in sorted_ld:
        instance_verdicts[idx] = labels[idx]
    verdict_map.append(instance_verdicts)

verdict_map
# Out:
# [{24: 'REFUTED', 15807: 'REFUTED'},
#  {65: 'SUPPORTED',
#   304: 'SUPPORTED',
#   8136: 'REFUTED',
#   11578: 'SUPPORTED',
#   13866: 'SUPPORTED',
#   13994: 'SUPPORTED',
#   15205: 'REFUTED'},
#  {175: 'SUPPORTED',
#   10551: 'NOT ENOUGH INFORMATION',
#   10837: 'NOT ENOUGH INFORMATION',
#   15050: 'NOT ENOUGH INFORMATION'},
#  {180: 'SUPPORTED',
#   3893: 'SUPPORTED',
#   6174: 'NOT ENOUGH INFORMATION',
#   15140: 'NOT ENOUGH INFORMATION'},
#  {328: 'SUPPORTED',
#   2046: 'SUPPORTED',
#   8701: 'SUPPORTED',
#   15091: 'NOT ENOUGH INFORMATION'},
#  {357: 'NOT ENOUGH INFORMATION',
#   8253: 'NOT ENOUGH INFORMATION',
#   16383: 'NOT ENOUGH INFORMATION'},
#  {360: 'NOT ENOUGH INFORMATION',
#   2969: 'NOT ENOUGH INFORMATION',
#   4174: 'NOT ENOUGH INFORMATION'},
#  {370: 'NOT ENOUGH INFORMATION', 8339: 'NOT ENOUGH INFORMATION'},
#  {401: 'REFUTED', 11004: 'REFUTED', 14926: 'NOT ENOUGH INFORMATION'},
#  {408: 'NOT ENOUGH INFORMATION', 1020: 'NOT ENOUGH INFORMATION'},
#  {427: 'SUPPORTED',
#   6590: 'SUPPORTED',
#   8625: 'SUPPORTED',
#   10556: 'SUPPORTED',
#   15060: 'SUPPORTED'},
#  {474: 'SUPPORTED', 1634: 'REFUTED'},
#  {476: 'SUPPORTED', 1005: 'SUPPORTED'},
#  {485: 'SUPPORTED', 3028: 'SUPPORTED', 9479: 'SUPPORTED', 14253: 'SUPPORTED'},
#  {536: 'NOT ENOUGH INFORMATION', 12638: 'SUPPORTED', 15146: 'SUPPORTED'},
#  {538: 'NOT ENOUGH INFORMATION',
#   8779: 'SUPPORTED',
#   11534: 'SUPPORTED',
#   14543: 'NOT ENOUGH INFORMATION'},
#  {582: 'SUPPORTED',
#   3307: 'SUPPORTED',
#   5385: 'SUPPORTED',
#   11561: 'NOT ENOUGH INFORMATION',
#   14791: 'NOT ENOUGH INFORMATION'},
#  {609: 'SUPPORTED', 5639: 'SUPPORTED', 14902: 'SUPPORTED'},
#  {732: 'NOT ENOUGH INFORMATION', 1295: 'NOT ENOUGH INFORMATION'},
#  {736: 'SUPPORTED', 12902: 'SUPPORTED', 15507: 'SUPPORTED'},
#  {871: 'SUPPORTED',
#   3324: 'REFUTED',
#   6448: 'NOT ENOUGH INFORMATION',
#   11019: 'NOT ENOUGH INFORMATION',
#   14511: 'NOT ENOUGH INFORMATION'},
#  {928: 'REFUTED',
#   3187: 'REFUTED',
#   6332: 'REFUTED',
#   6399: 'REFUTED',
#   9307: 'REFUTED',
#   9658: 'REFUTED',
#   12077: 'REFUTED'},
#  {930: 'REFUTED', 6903: 'SUPPORTED', 12306: 'SUPPORTED', 14322: 'SUPPORTED'},
#  {936: 'NOT ENOUGH INFORMATION',
#   5753: 'NOT ENOUGH INFORMATION',
#   13742: 'NOT ENOUGH INFORMATION',
#   15990: 'NOT ENOUGH INFORMATION'},
#  {969: 'SUPPORTED',
#   7511: 'NOT ENOUGH INFORMATION',
#   12619: 'NOT ENOUGH INFORMATION',
#   14295: 'NOT ENOUGH INFORMATION'},
#  {985: 'SUPPORTED', 6221: 'SUPPORTED', 12364: 'SUPPORTED'},
#  {1011: 'SUPPORTED', 7372: 'REFUTED', 14677: 'REFUTED'},
#  {1017: 'SUPPORTED', 6924: 'SUPPORTED', 9382: 'NOT ENOUGH INFORMATION'},
#  {1053: 'NOT ENOUGH INFORMATION', 14422: 'REFUTED'},
#  {280: 'REFUTED',
#   396: 'REFUTED',
#   1123: 'REFUTED',
#   1463: 'NOT ENOUGH INFORMATION',
#   1607: 'NOT ENOUGH INFORMATION',
#   1689: 'NOT ENOUGH INFORMATION'},
#  {1130: 'SUPPORTED', 14372: 'REFUTED'},
#  {1159: 'SUPPORTED',
#   8139: 'SUPPORTED',
#   11028: 'REFUTED',
#   11312: 'REFUTED',
#   13750: 'REFUTED',
#   15473: 'REFUTED'},
#  {1200: 'SUPPORTED', 1298: 'SUPPORTED'},
#  {599: 'SUPPORTED',
#   1201: 'NOT ENOUGH INFORMATION',
#   1526: 'NOT ENOUGH INFORMATION'},
#  {261: 'SUPPORTED', 1209: 'SUPPORTED'},
#  {1217: 'REFUTED',
#   5541: 'SUPPORTED',
#   8399: 'SUPPORTED',
#   12200: 'SUPPORTED',
#   16394: 'NOT ENOUGH INFORMATION'},
#  {1220: 'SUPPORTED',
#   3345: 'SUPPORTED',
#   6009: 'NOT ENOUGH INFORMATION',
#   8233: 'SUPPORTED',
#   14648: 'SUPPORTED'},
#  {1258: 'NOT ENOUGH INFORMATION', 14475: 'REFUTED'},
#  {655: 'REFUTED', 1259: 'REFUTED', 1612: 'REFUTED'},
#  {1305: 'SUPPORTED',
#   10582: 'SUPPORTED',
#   14017: 'SUPPORTED',
#   15605: 'SUPPORTED'},
#  {1323: 'SUPPORTED', 2663: 'SUPPORTED', 7243: 'SUPPORTED', 15670: 'SUPPORTED'},
#  {215: 'NOT ENOUGH INFORMATION', 1330: 'NOT ENOUGH INFORMATION'},
#  {1432: 'NOT ENOUGH INFORMATION', 15199: 'SUPPORTED'},
#  {1450: 'SUPPORTED', 5358: 'SUPPORTED', 14795: 'SUPPORTED'},
#  {1472: 'SUPPORTED',
#   3719: 'SUPPORTED',
#   5963: 'SUPPORTED',
#   7962: 'SUPPORTED',
#   14234: 'SUPPORTED'},
#  {1537: 'SUPPORTED', 1679: 'SUPPORTED', 5427: 'SUPPORTED'},
#  {1632: 'SUPPORTED',
#   2635: 'SUPPORTED',
#   4747: 'NOT ENOUGH INFORMATION',
#   8696: 'SUPPORTED',
#   14235: 'REFUTED'},
#  {1704: 'NOT ENOUGH INFORMATION', 14578: 'NOT ENOUGH INFORMATION'},
#  {1706: 'SUPPORTED', 13316: 'SUPPORTED', 14339: 'SUPPORTED'},
#  {1732: 'NOT ENOUGH INFORMATION',
#   8782: 'NOT ENOUGH INFORMATION',
#   11909: 'NOT ENOUGH INFORMATION',
#   13552: 'REFUTED',
#   14292: 'REFUTED'},
#  {1147: 'SUPPORTED', 1760: 'SUPPORTED'},
#  {1767: 'NOT ENOUGH INFORMATION',
#   3663: 'NOT ENOUGH INFORMATION',
#   3773: 'NOT ENOUGH INFORMATION'},
#  {1784: 'NOT ENOUGH INFORMATION',
#   5551: 'NOT ENOUGH INFORMATION',
#   11435: 'NOT ENOUGH INFORMATION',
#   16034: 'NOT ENOUGH INFORMATION'},
#  {30: 'SUPPORTED', 1785: 'SUPPORTED', 4407: 'SUPPORTED', 15191: 'SUPPORTED'},
#  {1819: 'SUPPORTED',
#   9278: 'NOT ENOUGH INFORMATION',
#   15971: 'NOT ENOUGH INFORMATION'},
#  {1857: 'REFUTED',
#   5655: 'REFUTED',
#   7313: 'REFUTED',
#   10140: 'NOT ENOUGH INFORMATION',
#   13997: 'NOT ENOUGH INFORMATION',
#   15346: 'REFUTED'},
#  {1888: 'NOT ENOUGH INFORMATION',
#   8034: 'NOT ENOUGH INFORMATION',
#   13762: 'NOT ENOUGH INFORMATION'},
#  {1910: 'SUPPORTED', 6150: 'SUPPORTED', 9791: 'NOT ENOUGH INFORMATION'},
#  {1946: 'NOT ENOUGH INFORMATION',
#   2815: 'SUPPORTED',
#   12647: 'NOT ENOUGH INFORMATION',
#   14909: 'NOT ENOUGH INFORMATION'},
#  {1967: 'SUPPORTED',
#   10835: 'SUPPORTED',
#   13031: 'SUPPORTED',
#   14332: 'SUPPORTED'},
#  {1971: 'NOT ENOUGH INFORMATION', 3268: 'NOT ENOUGH INFORMATION'},
#  {1977: 'SUPPORTED',
#   5266: 'SUPPORTED',
#   12197: 'SUPPORTED',
#   15362: 'SUPPORTED'},
#  {1990: 'SUPPORTED',
#   2702: 'SUPPORTED',
#   6967: 'REFUTED',
#   11409: 'REFUTED',
#   14060: 'REFUTED'},
#  {2033: 'SUPPORTED', 14181: 'NOT ENOUGH INFORMATION'},
#  {2060: 'REFUTED',
#   6285: 'REFUTED',
#   11726: 'NOT ENOUGH INFORMATION',
#   13422: 'NOT ENOUGH INFORMATION',
#   14162: 'REFUTED'},
#  {2065: 'NOT ENOUGH INFORMATION', 15798: 'NOT ENOUGH INFORMATION'},
#  {2088: 'NOT ENOUGH INFORMATION', 13637: 'SUPPORTED'},
#  {2113: 'SUPPORTED',
#   4598: 'SUPPORTED',
#   7373: 'SUPPORTED',
#   11773: 'SUPPORTED',
#   15785: 'NOT ENOUGH INFORMATION'},
#  {2120: 'SUPPORTED',
#   3763: 'SUPPORTED',
#   6708: 'SUPPORTED',
#   8793: 'SUPPORTED',
#   10331: 'SUPPORTED',
#   12654: 'SUPPORTED',
#   15532: 'NOT ENOUGH INFORMATION'},
#  {1260: 'SUPPORTED',
#   2134: 'SUPPORTED',
#   6890: 'SUPPORTED',
#   16054: 'NOT ENOUGH INFORMATION'},
#  {2140: 'REFUTED',
#   11749: 'NOT ENOUGH INFORMATION',
#   15158: 'NOT ENOUGH INFORMATION'},
#  {2201: 'REFUTED', 5549: 'SUPPORTED', 8703: 'SUPPORTED', 14123: 'SUPPORTED'},
#  {2248: 'SUPPORTED', 14878: 'SUPPORTED'},
#  {2254: 'SUPPORTED', 10581: 'SUPPORTED', 15894: 'SUPPORTED'},
#  {2260: 'SUPPORTED', 14959: 'NOT ENOUGH INFORMATION'},
#  {2267: 'SUPPORTED', 12791: 'SUPPORTED', 15326: 'NOT ENOUGH INFORMATION'},
#  {227: 'SUPPORTED', 2338: 'SUPPORTED'},
#  {2344: 'NOT ENOUGH INFORMATION', 5911: 'NOT ENOUGH INFORMATION'},
#  {2362: 'REFUTED', 9989: 'REFUTED', 14262: 'REFUTED'},
#  {2363: 'SUPPORTED',
#   9475: 'SUPPORTED',
#   12665: 'NOT ENOUGH INFORMATION',
#   15076: 'NOT ENOUGH INFORMATION'},
#  {2444: 'REFUTED', 8543: 'REFUTED', 16127: 'REFUTED'},
#  {2504: 'SUPPORTED',
#   6405: 'SUPPORTED',
#   13197: 'SUPPORTED',
#   14723: 'SUPPORTED'},
#  {2652: 'REFUTED',
#   8141: 'NOT ENOUGH INFORMATION',
#   16238: 'NOT ENOUGH INFORMATION'},
#  {2659: 'NOT ENOUGH INFORMATION', 7860: 'SUPPORTED'},
#  {2664: 'SUPPORTED',
#   3993: 'SUPPORTED',
#   5303: 'SUPPORTED',
#   14492: 'NOT ENOUGH INFORMATION'},
#  {2696: 'NOT ENOUGH INFORMATION', 8875: 'NOT ENOUGH INFORMATION'},
#  {2706: 'SUPPORTED', 7238: 'SUPPORTED', 14667: 'NOT ENOUGH INFORMATION'},
#  {232: 'NOT ENOUGH INFORMATION',
#   2720: 'SUPPORTED',
#   10845: 'SUPPORTED',
#   13189: 'SUPPORTED',
#   14503: 'NOT ENOUGH INFORMATION'},
#  {2726: 'SUPPORTED', 14695: 'NOT ENOUGH INFORMATION'},
#  {2753: 'REFUTED', 14530: 'NOT ENOUGH INFORMATION'},
#  {1502: 'NOT ENOUGH INFORMATION',
#   2764: 'NOT ENOUGH INFORMATION',
#   16390: 'NOT ENOUGH INFORMATION'},
#  {2810: 'SUPPORTED', 12213: 'SUPPORTED', 12524: 'SUPPORTED'},
#  {2811: 'SUPPORTED', 4589: 'NOT ENOUGH INFORMATION'},
#  {2824: 'REFUTED', 7674: 'SUPPORTED', 13806: 'SUPPORTED', 14293: 'SUPPORTED'},
#  {2849: 'REFUTED', 6341: 'REFUTED', 8967: 'REFUTED'},
#  {2858: 'NOT ENOUGH INFORMATION', 3109: 'NOT ENOUGH INFORMATION'},
#  {2872: 'SUPPORTED', 12903: 'SUPPORTED', 15521: 'SUPPORTED'},
#  {1483: 'SUPPORTED', 2881: 'SUPPORTED', 16219: 'SUPPORTED'},
#  {2189: 'SUPPORTED',
#   2885: 'SUPPORTED',
#   6509: 'SUPPORTED',
#   11750: 'SUPPORTED',
#   15023: 'SUPPORTED'},
#  {2919: 'SUPPORTED',
#   8060: 'SUPPORTED',
#   11598: 'SUPPORTED',
#   13758: 'SUPPORTED',
#   14618: 'SUPPORTED'},
#  {2939: 'SUPPORTED',
#   8963: 'SUPPORTED',
#   13066: 'SUPPORTED',
#   16385: 'SUPPORTED'},
#  {2944: 'NOT ENOUGH INFORMATION',
#   11022: 'NOT ENOUGH INFORMATION',
#   16007: 'NOT ENOUGH INFORMATION'},
#  {2955: 'NOT ENOUGH INFORMATION', 4196: 'NOT ENOUGH INFORMATION'},
#  {2968: 'SUPPORTED', 9619: 'NOT ENOUGH INFORMATION'},
#  {3000: 'REFUTED', 9422: 'REFUTED', 13623: 'REFUTED', 15372: 'REFUTED'},
#  {3011: 'NOT ENOUGH INFORMATION', 14350: 'NOT ENOUGH INFORMATION'},
#  {3026: 'NOT ENOUGH INFORMATION', 12341: 'REFUTED', 15226: 'REFUTED'},
#  {3041: 'NOT ENOUGH INFORMATION', 14733: 'NOT ENOUGH INFORMATION'},
#  {3045: 'REFUTED', 14654: 'SUPPORTED'},
#  {3089: 'REFUTED', 7781: 'SUPPORTED'},
#  {3098: 'NOT ENOUGH INFORMATION',
#   12759: 'NOT ENOUGH INFORMATION',
#   14651: 'NOT ENOUGH INFORMATION'},
#  {3118: 'REFUTED', 15823: 'REFUTED'},
#  {3120: 'NOT ENOUGH INFORMATION',
#   12922: 'NOT ENOUGH INFORMATION',
#   16036: 'REFUTED'},
#  {1696: 'SUPPORTED',
#   3195: 'NOT ENOUGH INFORMATION',
#   8092: 'SUPPORTED',
#   11043: 'SUPPORTED'},
#  {3206: 'SUPPORTED',
#   8533: 'SUPPORTED',
#   10135: 'SUPPORTED',
#   14662: 'SUPPORTED'},
#  {3225: 'SUPPORTED', 14659: 'NOT ENOUGH INFORMATION'},
#  {3241: 'NOT ENOUGH INFORMATION',
#   5845: 'REFUTED',
#   8326: 'REFUTED',
#   14923: 'SUPPORTED'},
#  {3274: 'REFUTED', 12938: 'SUPPORTED'},
#  {3278: 'REFUTED', 13174: 'REFUTED', 14901: 'NOT ENOUGH INFORMATION'},
#  {3280: 'SUPPORTED', 15359: 'SUPPORTED'},
#  {3336: 'NOT ENOUGH INFORMATION',
#   7182: 'NOT ENOUGH INFORMATION',
#   13963: 'NOT ENOUGH INFORMATION',
#   15385: 'NOT ENOUGH INFORMATION'},
#  {3346: 'SUPPORTED', 7022: 'SUPPORTED'},
#  {3352: 'NOT ENOUGH INFORMATION',
#   5533: 'NOT ENOUGH INFORMATION',
#   15660: 'NOT ENOUGH INFORMATION'},
#  {3414: 'NOT ENOUGH INFORMATION',
#   5908: 'NOT ENOUGH INFORMATION',
#   8142: 'NOT ENOUGH INFORMATION',
#   15879: 'NOT ENOUGH INFORMATION'},
#  {3492: 'REFUTED', 15439: 'REFUTED'},
#  {169: 'NOT ENOUGH INFORMATION',
#   3552: 'NOT ENOUGH INFORMATION',
#   3772: 'NOT ENOUGH INFORMATION'},
#  {3560: 'REFUTED',
#   8885: 'NOT ENOUGH INFORMATION',
#   10374: 'NOT ENOUGH INFORMATION'},
#  {3561: 'NOT ENOUGH INFORMATION', 9623: 'NOT ENOUGH INFORMATION'},
#  {3569: 'NOT ENOUGH INFORMATION',
#   11029: 'NOT ENOUGH INFORMATION',
#   13199: 'NOT ENOUGH INFORMATION',
#   15234: 'REFUTED'},
#  {3593: 'REFUTED', 14547: 'REFUTED'},
#  {3665: 'SUPPORTED', 10367: 'NOT ENOUGH INFORMATION'},
#  {1386: 'SUPPORTED', 3666: 'SUPPORTED', 14949: 'NOT ENOUGH INFORMATION'},
#  {555: 'SUPPORTED', 3712: 'SUPPORTED', 15291: 'SUPPORTED'},
#  {3755: 'SUPPORTED', 13349: 'SUPPORTED', 14726: 'SUPPORTED'},
#  {3756: 'SUPPORTED', 13343: 'SUPPORTED', 14718: 'SUPPORTED'},
#  {3775: 'NOT ENOUGH INFORMATION',
#   10995: 'NOT ENOUGH INFORMATION',
#   11159: 'NOT ENOUGH INFORMATION',
#   14781: 'NOT ENOUGH INFORMATION'},
#  {3801: 'REFUTED', 8962: 'REFUTED', 11594: 'REFUTED', 15116: 'REFUTED'},
#  {2191: 'REFUTED',
#   3829: 'NOT ENOUGH INFORMATION',
#   5242: 'NOT ENOUGH INFORMATION',
#   14813: 'REFUTED'},
#  {3847: 'NOT ENOUGH INFORMATION',
#   10702: 'SUPPORTED',
#   12784: 'SUPPORTED',
#   13590: 'SUPPORTED',
#   14806: 'SUPPORTED'},
#  {3885: 'SUPPORTED', 7501: 'SUPPORTED', 12525: 'SUPPORTED'},
#  {3716: 'REFUTED',
#   3904: 'REFUTED',
#   8045: 'REFUTED',
#   11295: 'REFUTED',
#   15497: 'NOT ENOUGH INFORMATION'},
#  {4033: 'SUPPORTED',
#   10334: 'NOT ENOUGH INFORMATION',
#   12497: 'SUPPORTED',
#   13334: 'NOT ENOUGH INFORMATION',
#   13989: 'SUPPORTED',
#   15541: 'SUPPORTED'},
#  {4045: 'SUPPORTED',
#   8530: 'SUPPORTED',
#   11916: 'SUPPORTED',
#   14309: 'SUPPORTED'},
#  {2119: 'REFUTED', 4048: 'REFUTED', 12317: 'SUPPORTED', 14914: 'SUPPORTED'},
#  {4074: 'SUPPORTED', 15643: 'SUPPORTED'},
#  {4098: 'SUPPORTED',
#   7675: 'SUPPORTED',
#   12462: 'SUPPORTED',
#   14299: 'NOT ENOUGH INFORMATION'},
#  {4112: 'NOT ENOUGH INFORMATION', 4590: 'NOT ENOUGH INFORMATION'},
#  {4140: 'SUPPORTED', 12511: 'SUPPORTED', 16005: 'NOT ENOUGH INFORMATION'},
#  {4153: 'REFUTED', 4183: 'REFUTED', 13331: 'REFUTED', 14481: 'REFUTED'},
#  {4163: 'SUPPORTED', 16149: 'SUPPORTED'},
#  {4168: 'SUPPORTED', 13062: 'SUPPORTED', 15217: 'SUPPORTED'},
#  {181: 'SUPPORTED', 4172: 'SUPPORTED'},
#  {4202: 'NOT ENOUGH INFORMATION', 15614: 'NOT ENOUGH INFORMATION'},
#  {4249: 'SUPPORTED',
#   11940: 'NOT ENOUGH INFORMATION',
#   15619: 'NOT ENOUGH INFORMATION'},
#  {4257: 'SUPPORTED', 9543: 'SUPPORTED', 14836: 'SUPPORTED'},
#  {4258: 'SUPPORTED', 12507: 'SUPPORTED', 14107: 'SUPPORTED'},
#  {4280: 'NOT ENOUGH INFORMATION',
#   9099: 'NOT ENOUGH INFORMATION',
#   11782: 'SUPPORTED',
#   14610: 'SUPPORTED'},
#  {4333: 'SUPPORTED', 14222: 'SUPPORTED'},
#  {4345: 'SUPPORTED',
#   5779: 'NOT ENOUGH INFORMATION',
#   16058: 'NOT ENOUGH INFORMATION'},
#  {4358: 'SUPPORTED',
#   7846: 'SUPPORTED',
#   10347: 'SUPPORTED',
#   13743: 'SUPPORTED',
#   15101: 'SUPPORTED'},
#  {4403: 'REFUTED', 9931: 'REFUTED', 14474: 'REFUTED'},
#  {629: 'SUPPORTED', 4404: 'NOT ENOUGH INFORMATION'},
#  {913: 'SUPPORTED',
#   4409: 'SUPPORTED',
#   13194: 'NOT ENOUGH INFORMATION',
#   16157: 'NOT ENOUGH INFORMATION'},
#  {2977: 'NOT ENOUGH INFORMATION',
#   4457: 'NOT ENOUGH INFORMATION',
#   4595: 'NOT ENOUGH INFORMATION'},
#  {4467: 'REFUTED', 13166: 'REFUTED', 14455: 'REFUTED'},
#  {4473: 'NOT ENOUGH INFORMATION',
#   7677: 'SUPPORTED',
#   10538: 'NOT ENOUGH INFORMATION',
#   14650: 'NOT ENOUGH INFORMATION'},
#  {4508: 'NOT ENOUGH INFORMATION',
#   9023: 'REFUTED',
#   14047: 'NOT ENOUGH INFORMATION'},
#  {4213: 'REFUTED', 4512: 'NOT ENOUGH INFORMATION', 15003: 'REFUTED'},
#  {4248: 'REFUTED',
#   4276: 'REFUTED',
#   4513: 'REFUTED',
#   6267: 'REFUTED',
#   8459: 'REFUTED',
#   14089: 'REFUTED'},
#  {4514: 'SUPPORTED',
#   6557: 'SUPPORTED',
#   10839: 'SUPPORTED',
#   13591: 'REFUTED',
#   14363: 'REFUTED'},
#  {4521: 'NOT ENOUGH INFORMATION', 13082: 'NOT ENOUGH INFORMATION'},
#  {2797: 'NOT ENOUGH INFORMATION',
#   4527: 'REFUTED',
#   7158: 'REFUTED',
#   15071: 'REFUTED'},
#  {4529: 'SUPPORTED',
#   11565: 'SUPPORTED',
#   11942: 'SUPPORTED',
#   15630: 'SUPPORTED'},
#  {4544: 'NOT ENOUGH INFORMATION', 9179: 'SUPPORTED'},
#  {4565: 'SUPPORTED', 10870: 'SUPPORTED'},
#  {4204: 'NOT ENOUGH INFORMATION', 4594: 'NOT ENOUGH INFORMATION'},
#  {4641: 'NOT ENOUGH INFORMATION', 15179: 'NOT ENOUGH INFORMATION'},
#  {1222: 'SUPPORTED', 4722: 'SUPPORTED', 9219: 'SUPPORTED'},
#  {4787: 'NOT ENOUGH INFORMATION', 4919: 'NOT ENOUGH INFORMATION'},
#  {1749: 'NOT ENOUGH INFORMATION',
#   4832: 'NOT ENOUGH INFORMATION',
#   6896: 'NOT ENOUGH INFORMATION',
#   9211: 'NOT ENOUGH INFORMATION',
#   11756: 'NOT ENOUGH INFORMATION',
#   14692: 'NOT ENOUGH INFORMATION'},
#  {4834: 'NOT ENOUGH INFORMATION', 15515: 'NOT ENOUGH INFORMATION'},
#  {4841: 'NOT ENOUGH INFORMATION', 11046: 'NOT ENOUGH INFORMATION'},
#  {4842: 'NOT ENOUGH INFORMATION', 13460: 'SUPPORTED', 15669: 'SUPPORTED'},
#  {1808: 'NOT ENOUGH INFORMATION',
#   4856: 'SUPPORTED',
#   8148: 'NOT ENOUGH INFORMATION'},
#  {311: 'SUPPORTED', 4864: 'SUPPORTED', 7114: 'SUPPORTED', 15801: 'REFUTED'},
#  {4880: 'NOT ENOUGH INFORMATION',
#   8695: 'NOT ENOUGH INFORMATION',
#   11297: 'NOT ENOUGH INFORMATION',
#   15539: 'NOT ENOUGH INFORMATION'},
#  {4902: 'NOT ENOUGH INFORMATION', 14550: 'SUPPORTED'},
#  {4944: 'REFUTED', 10585: 'SUPPORTED'},
#  {4958: 'SUPPORTED', 5735: 'NOT ENOUGH INFORMATION'},
#  {4968: 'SUPPORTED', 10193: 'SUPPORTED'},
#  {4971: 'NOT ENOUGH INFORMATION',
#   12781: 'NOT ENOUGH INFORMATION',
#   15039: 'REFUTED'},
#  {5002: 'NOT ENOUGH INFORMATION', 14195: 'SUPPORTED'},
#  {5003: 'NOT ENOUGH INFORMATION',
#   8125: 'NOT ENOUGH INFORMATION',
#   14287: 'NOT ENOUGH INFORMATION'},
#  {5016: 'SUPPORTED', 11033: 'SUPPORTED', 16099: 'SUPPORTED'},
#  {5043: 'NOT ENOUGH INFORMATION', 12701: 'SUPPORTED', 13204: 'SUPPORTED'},
#  {5059: 'SUPPORTED', 8340: 'SUPPORTED'},
#  {5063: 'NOT ENOUGH INFORMATION',
#   6683: 'SUPPORTED',
#   11439: 'SUPPORTED',
#   14390: 'SUPPORTED'},
#  {5072: 'REFUTED', 14111: 'NOT ENOUGH INFORMATION'},
#  {5089: 'NOT ENOUGH INFORMATION', 15764: 'NOT ENOUGH INFORMATION'},
#  {5090: 'NOT ENOUGH INFORMATION', 5508: 'NOT ENOUGH INFORMATION'},
#  {5100: 'SUPPORTED',
#   7215: 'SUPPORTED',
#   12196: 'SUPPORTED',
#   14951: 'SUPPORTED'},
#  {5110: 'NOT ENOUGH INFORMATION', 14438: 'NOT ENOUGH INFORMATION'},
#  {3651: 'SUPPORTED', 5153: 'SUPPORTED', 5748: 'SUPPORTED', 14366: 'REFUTED'},
#  {856: 'SUPPORTED',
#   5159: 'REFUTED',
#   13032: 'NOT ENOUGH INFORMATION',
#   13170: 'NOT ENOUGH INFORMATION',
#   14895: 'NOT ENOUGH INFORMATION'},
#  {3291: 'NOT ENOUGH INFORMATION',
#   5184: 'NOT ENOUGH INFORMATION',
#   7514: 'NOT ENOUGH INFORMATION',
#   14559: 'NOT ENOUGH INFORMATION'},
#  {5271: 'NOT ENOUGH INFORMATION',
#   13153: 'NOT ENOUGH INFORMATION',
#   14647: 'NOT ENOUGH INFORMATION'},
#  {2288: 'SUPPORTED',
#   5287: 'SUPPORTED',
#   8332: 'NOT ENOUGH INFORMATION',
#   10189: 'SUPPORTED',
#   12671: 'SUPPORTED',
#   14380: 'SUPPORTED'},
#  {2111: 'REFUTED',
#   5305: 'REFUTED',
#   8057: 'REFUTED',
#   8398: 'REFUTED',
#   11786: 'REFUTED',
#   12008: 'REFUTED',
#   16045: 'REFUTED'},
#  {5312: 'NOT ENOUGH INFORMATION',
#   8474: 'NOT ENOUGH INFORMATION',
#   16460: 'NOT ENOUGH INFORMATION'},
#  {5345: 'NOT ENOUGH INFORMATION', 14051: 'NOT ENOUGH INFORMATION'},
#  {5387: 'NOT ENOUGH INFORMATION', 10035: 'SUPPORTED', 14463: 'SUPPORTED'},
#  {5388: 'REFUTED', 5394: 'REFUTED'},
#  {542: 'NOT ENOUGH INFORMATION', 5397: 'NOT ENOUGH INFORMATION'},
#  {5410: 'NOT ENOUGH INFORMATION', 15571: 'SUPPORTED'},
#  {5424: 'SUPPORTED', 14794: 'SUPPORTED'},
#  {5441: 'SUPPORTED', 14171: 'NOT ENOUGH INFORMATION'},
#  {5442: 'SUPPORTED', 13300: 'SUPPORTED', 14187: 'SUPPORTED'},
#  {5464: 'SUPPORTED', 8258: 'SUPPORTED', 14135: 'SUPPORTED'},
#  {5480: 'NOT ENOUGH INFORMATION', 15650: 'NOT ENOUGH INFORMATION'},
#  {5497: 'NOT ENOUGH INFORMATION', 12354: 'NOT ENOUGH INFORMATION'},
#  {1624: 'REFUTED',
#   5543: 'REFUTED',
#   8697: 'REFUTED',
#   11167: 'REFUTED',
#   15914: 'SUPPORTED'},
#  {1650: 'SUPPORTED',
#   5553: 'SUPPORTED',
#   13044: 'SUPPORTED',
#   15717: 'NOT ENOUGH INFORMATION'},
#  {5560: 'SUPPORTED', 13611: 'SUPPORTED', 14954: 'SUPPORTED'},
#  {5616: 'REFUTED', 14119: 'NOT ENOUGH INFORMATION'},
#  {5140: 'SUPPORTED',
#   5618: 'SUPPORTED',
#   10851: 'SUPPORTED',
#   15567: 'SUPPORTED'},
#  {5642: 'SUPPORTED', 12518: 'SUPPORTED'},
#  {2359: 'NOT ENOUGH INFORMATION',
#   5665: 'SUPPORTED',
#   6139: 'NOT ENOUGH INFORMATION'},
#  {5675: 'NOT ENOUGH INFORMATION', 14285: 'NOT ENOUGH INFORMATION'},
#  {5680: 'SUPPORTED',
#   10715: 'NOT ENOUGH INFORMATION',
#   12050: 'NOT ENOUGH INFORMATION',
#   14133: 'NOT ENOUGH INFORMATION'},
#  {5704: 'NOT ENOUGH INFORMATION', 15087: 'SUPPORTED'},
#  {4660: 'SUPPORTED', 5714: 'SUPPORTED'},
#  {5031: 'REFUTED', 5734: 'NOT ENOUGH INFORMATION'},
#  {4284: 'NOT ENOUGH INFORMATION', 5736: 'NOT ENOUGH INFORMATION'},
#  {5101: 'REFUTED', 5737: 'NOT ENOUGH INFORMATION'},
#  {5752: 'SUPPORTED', 12457: 'SUPPORTED', 14625: 'SUPPORTED'},
#  {1840: 'SUPPORTED',
#   2717: 'SUPPORTED',
#   5764: 'SUPPORTED',
#   7600: 'SUPPORTED',
#   10078: 'SUPPORTED',
#   11548: 'SUPPORTED',
#   13020: 'REFUTED',
#   14313: 'REFUTED'},
#  {5766: 'NOT ENOUGH INFORMATION', 11038: 'NOT ENOUGH INFORMATION'},
#  {5793: 'NOT ENOUGH INFORMATION',
#   7961: 'NOT ENOUGH INFORMATION',
#   10703: 'REFUTED',
#   12655: 'REFUTED',
#   13986: 'REFUTED',
#   15907: 'SUPPORTED'},
#  {5808: 'NOT ENOUGH INFORMATION', 14062: 'NOT ENOUGH INFORMATION'},
#  {5889: 'NOT ENOUGH INFORMATION',
#   8134: 'NOT ENOUGH INFORMATION',
#   10039: 'NOT ENOUGH INFORMATION',
#   13458: 'SUPPORTED',
#   15078: 'SUPPORTED'},
#  {5897: 'SUPPORTED', 11764: 'SUPPORTED', 15743: 'SUPPORTED'},
#  {5899: 'NOT ENOUGH INFORMATION', 14805: 'NOT ENOUGH INFORMATION'},
#  {5915: 'REFUTED', 12356: 'NOT ENOUGH INFORMATION'},
#  {5925: 'NOT ENOUGH INFORMATION', 14213: 'NOT ENOUGH INFORMATION'},
#  {5928: 'SUPPORTED', 11587: 'SUPPORTED', 15230: 'SUPPORTED'},
#  {5960: 'NOT ENOUGH INFORMATION',
#   8329: 'NOT ENOUGH INFORMATION',
#   11572: 'NOT ENOUGH INFORMATION',
#   13597: 'NOT ENOUGH INFORMATION',
#   15194: 'NOT ENOUGH INFORMATION'},
#  {5979: 'SUPPORTED', 11007: 'SUPPORTED', 15758: 'NOT ENOUGH INFORMATION'},
#  {1244: 'NOT ENOUGH INFORMATION', 5984: 'SUPPORTED', 9733: 'SUPPORTED'},
#  {3680: 'REFUTED',
#   6016: 'REFUTED',
#   8140: 'REFUTED',
#   12343: 'REFUTED',
#   15866: 'NOT ENOUGH INFORMATION'},
#  {3871: 'NOT ENOUGH INFORMATION', 6145: 'NOT ENOUGH INFORMATION'},
#  {6168: 'NOT ENOUGH INFORMATION',
#   8692: 'REFUTED',
#   13435: 'REFUTED',
#   15147: 'REFUTED'},
#  {6170: 'REFUTED', 14589: 'REFUTED'},
#  {6171: 'SUPPORTED', 14852: 'SUPPORTED'},
#  {6172: 'SUPPORTED', 14863: 'SUPPORTED'},
#  {6173: 'NOT ENOUGH INFORMATION', 15685: 'SUPPORTED'},
#  {6183: 'SUPPORTED',
#   11013: 'SUPPORTED',
#   13462: 'SUPPORTED',
#   15343: 'SUPPORTED'},
#  {421: 'SUPPORTED',
#   1828: 'NOT ENOUGH INFORMATION',
#   5205: 'NOT ENOUGH INFORMATION',
#   6203: 'NOT ENOUGH INFORMATION'},
#  {6209: 'REFUTED', 10996: 'REFUTED', 15395: 'REFUTED'},
#  {6218: 'REFUTED', 14605: 'REFUTED'},
#  {6226: 'SUPPORTED', 15259: 'SUPPORTED'},
#  {6229: 'NOT ENOUGH INFORMATION', 14127: 'SUPPORTED'},
#  {6232: 'SUPPORTED', 10871: 'SUPPORTED'},
#  {794: 'SUPPORTED', 6233: 'SUPPORTED', 15468: 'SUPPORTED'},
#  {6238: 'NOT ENOUGH INFORMATION',
#   9981: 'SUPPORTED',
#   13598: 'SUPPORTED',
#   14707: 'SUPPORTED'},
#  {2918: 'SUPPORTED',
#   6240: 'NOT ENOUGH INFORMATION',
#   14450: 'NOT ENOUGH INFORMATION'},
#  {6241: 'SUPPORTED',
#   7949: 'SUPPORTED',
#   13429: 'SUPPORTED',
#   14437: 'SUPPORTED'},
#  {6265: 'SUPPORTED', 10575: 'SUPPORTED', 14261: 'NOT ENOUGH INFORMATION'},
#  {6271: 'SUPPORTED',
#   11730: 'SUPPORTED',
#   13423: 'SUPPORTED',
#   14163: 'SUPPORTED'},
#  {1157: 'SUPPORTED',
#   4285: 'SUPPORTED',
#   6306: 'SUPPORTED',
#   8616: 'SUPPORTED',
#   14316: 'NOT ENOUGH INFORMATION'},
#  {6312: 'NOT ENOUGH INFORMATION', 15967: 'REFUTED'},
#  {1594: 'SUPPORTED',
#   6314: 'SUPPORTED',
#   12796: 'NOT ENOUGH INFORMATION',
#   15674: 'REFUTED'},
#  {6348: 'REFUTED', 14853: 'NOT ENOUGH INFORMATION'},
#  {6361: 'SUPPORTED', 10543: 'SUPPORTED', 14082: 'SUPPORTED'},
#  {6370: 'REFUTED', 9678: 'REFUTED', 15956: 'SUPPORTED'},
#  {6372: 'NOT ENOUGH INFORMATION', 15407: 'NOT ENOUGH INFORMATION'},
#  {6385: 'SUPPORTED', 16182: 'SUPPORTED'},
#  {6394: 'NOT ENOUGH INFORMATION',
#   10333: 'NOT ENOUGH INFORMATION',
#   15309: 'NOT ENOUGH INFORMATION'},
#  {6397: 'SUPPORTED', 14478: 'SUPPORTED'},
#  {6428: 'SUPPORTED', 15389: 'SUPPORTED'},
#  {6435: 'SUPPORTED',
#   8462: 'SUPPORTED',
#   13981: 'SUPPORTED',
#   15303: 'SUPPORTED'},
#  {6478: 'NOT ENOUGH INFORMATION', 15455: 'NOT ENOUGH INFORMATION'},
#  {6505: 'SUPPORTED', 10587: 'NOT ENOUGH INFORMATION'},
#  {6506: 'SUPPORTED',
#   12325: 'NOT ENOUGH INFORMATION',
#   14367: 'NOT ENOUGH INFORMATION'},
#  {3810: 'NOT ENOUGH INFORMATION',
#   6521: 'NOT ENOUGH INFORMATION',
#   8866: 'NOT ENOUGH INFORMATION'},
#  {6528: 'NOT ENOUGH INFORMATION', 10719: 'NOT ENOUGH INFORMATION'},
#  {6545: 'NOT ENOUGH INFORMATION', 12351: 'NOT ENOUGH INFORMATION'},
#  {3141: 'SUPPORTED',
#   6570: 'NOT ENOUGH INFORMATION',
#   11171: 'NOT ENOUGH INFORMATION',
#   14239: 'NOT ENOUGH INFORMATION'},
#  {3138: 'SUPPORTED',
#   6594: 'SUPPORTED',
#   9937: 'SUPPORTED',
#   12195: 'SUPPORTED',
#   13736: 'REFUTED',
#   15090: 'SUPPORTED'},
#  {6621: 'NOT ENOUGH INFORMATION', 11319: 'NOT ENOUGH INFORMATION'},
#  {6661: 'SUPPORTED', 15215: 'NOT ENOUGH INFORMATION'},
#  {6665: 'NOT ENOUGH INFORMATION', 11555: 'REFUTED', 14893: 'REFUTED'},
#  {4533: 'NOT ENOUGH INFORMATION',
#   6667: 'NOT ENOUGH INFORMATION',
#   14899: 'NOT ENOUGH INFORMATION'},
#  {1194: 'NOT ENOUGH INFORMATION',
#   6681: 'NOT ENOUGH INFORMATION',
#   10038: 'NOT ENOUGH INFORMATION',
#   14823: 'NOT ENOUGH INFORMATION'},
#  {2714: 'SUPPORTED',
#   6698: 'NOT ENOUGH INFORMATION',
#   12315: 'NOT ENOUGH INFORMATION',
#   15287: 'NOT ENOUGH INFORMATION'},
#  {6701: 'REFUTED', 10125: 'REFUTED', 14271: 'SUPPORTED'},
#  {6721: 'SUPPORTED', 11567: 'SUPPORTED', 15421: 'NOT ENOUGH INFORMATION'},
#  {6737: 'NOT ENOUGH INFORMATION',
#   9617: 'REFUTED',
#   12927: 'REFUTED',
#   14865: 'REFUTED'},
#  {6742: 'SUPPORTED',
#   10362: 'SUPPORTED',
#   11035: 'SUPPORTED',
#   14982: 'SUPPORTED'},
#  {1933: 'REFUTED', 5460: 'NOT ENOUGH INFORMATION', 6771: 'SUPPORTED'},
#  {1765: 'SUPPORTED', 6776: 'SUPPORTED', 10722: 'SUPPORTED'},
#  {6779: 'SUPPORTED', 12199: 'SUPPORTED', 14388: 'SUPPORTED'},
#  {2921: 'SUPPORTED',
#   6781: 'SUPPORTED',
#   11981: 'SUPPORTED',
#   15959: 'SUPPORTED'},
#  {2067: 'SUPPORTED',
#   5462: 'NOT ENOUGH INFORMATION',
#   6784: 'NOT ENOUGH INFORMATION'},
#  {5461: 'REFUTED', 6819: 'SUPPORTED'},
#  {6765: 'NOT ENOUGH INFORMATION',
#   6827: 'NOT ENOUGH INFORMATION',
#   12782: 'NOT ENOUGH INFORMATION',
#   15052: 'NOT ENOUGH INFORMATION'},
#  {6854: 'SUPPORTED', 9877: 'SUPPORTED', 14037: 'SUPPORTED'},
#  {6864: 'REFUTED', 14991: 'REFUTED'},
#  {6877: 'NOT ENOUGH INFORMATION',
#   11133: 'NOT ENOUGH INFORMATION',
#   13891: 'NOT ENOUGH INFORMATION'},
#  {6889: 'NOT ENOUGH INFORMATION', 14402: 'SUPPORTED'},
#  {6893: 'NOT ENOUGH INFORMATION', 10557: 'SUPPORTED', 14099: 'SUPPORTED'},
#  {6901: 'SUPPORTED', 9839: 'SUPPORTED', 15135: 'SUPPORTED'},
#  {6904: 'NOT ENOUGH INFORMATION',
#   10337: 'SUPPORTED',
#   14819: 'NOT ENOUGH INFORMATION'},
#  {6906: 'NOT ENOUGH INFORMATION', 14562: 'NOT ENOUGH INFORMATION'},
#  {6913: 'REFUTED', 13884: 'REFUTED', 16491: 'REFUTED'},
#  {1578: 'SUPPORTED', 3930: 'SUPPORTED', 6936: 'SUPPORTED', 14889: 'SUPPORTED'},
#  {6956: 'SUPPORTED', 11950: 'SUPPORTED', 15647: 'SUPPORTED'},
#  {2321: 'SUPPORTED', 6968: 'SUPPORTED', 15069: 'SUPPORTED'},
#  {6976: 'NOT ENOUGH INFORMATION', 13473: 'SUPPORTED'},
#  {6985: 'NOT ENOUGH INFORMATION', 14882: 'SUPPORTED'},
#  {7001: 'SUPPORTED',
#   8685: 'SUPPORTED',
#   11138: 'SUPPORTED',
#   14276: 'SUPPORTED'},
#  {7006: 'NOT ENOUGH INFORMATION', 13639: 'NOT ENOUGH INFORMATION'},
#  {7008: 'SUPPORTED', 9851: 'NOT ENOUGH INFORMATION'},
#  {4559: 'SUPPORTED', 7012: 'SUPPORTED', 10372: 'NOT ENOUGH INFORMATION'},
#  {6952: 'SUPPORTED', 7016: 'SUPPORTED', 9843: 'SUPPORTED', 15049: 'SUPPORTED'},
#  {7021: 'SUPPORTED', 9853: 'NOT ENOUGH INFORMATION'},
#  {7042: 'NOT ENOUGH INFORMATION', 14467: 'NOT ENOUGH INFORMATION'},
#  {7051: 'NOT ENOUGH INFORMATION', 15028: 'NOT ENOUGH INFORMATION'},
#  {7076: 'REFUTED', 13847: 'REFUTED', 14685: 'REFUTED'},
#  {1727: 'SUPPORTED',
#   7096: 'SUPPORTED',
#   11789: 'SUPPORTED',
#   14973: 'SUPPORTED'},
#  {7115: 'REFUTED', 15463: 'SUPPORTED'},
#  {491: 'REFUTED', 7130: 'REFUTED', 14383: 'REFUTED'},
#  {7144: 'NOT ENOUGH INFORMATION', 14703: 'NOT ENOUGH INFORMATION'},
#  {7160: 'SUPPORTED', 15601: 'REFUTED'},
#  {7184: 'SUPPORTED', 11306: 'SUPPORTED', 11966: 'REFUTED', 15551: 'REFUTED'},
#  {340: 'REFUTED', 7186: 'REFUTED', 11771: 'REFUTED', 15443: 'REFUTED'},
#  {2312: 'SUPPORTED',
#   7192: 'SUPPORTED',
#   12644: 'SUPPORTED',
#   14470: 'SUPPORTED'},
#  {7201: 'REFUTED', 15487: 'REFUTED'},
#  {7264: 'REFUTED',
#   7526: 'REFUTED',
#   11788: 'REFUTED',
#   16386: 'NOT ENOUGH INFORMATION'},
#  {7269: 'REFUTED', 14790: 'REFUTED'},
#  {7276: 'SUPPORTED', 13167: 'SUPPORTED', 14460: 'SUPPORTED'},
#  {7294: 'SUPPORTED', 14063: 'SUPPORTED'},
#  {4054: 'SUPPORTED', 7300: 'NOT ENOUGH INFORMATION'},
#  {7309: 'SUPPORTED', 13079: 'SUPPORTED'},
#  {1856: 'SUPPORTED', 7312: 'SUPPORTED', 14007: 'REFUTED', 15365: 'REFUTED'},
#  {7314: 'NOT ENOUGH INFORMATION',
#   9845: 'NOT ENOUGH INFORMATION',
#   12188: 'NOT ENOUGH INFORMATION',
#   15766: 'NOT ENOUGH INFORMATION'},
#  {1066: 'NOT ENOUGH INFORMATION',
#   7322: 'NOT ENOUGH INFORMATION',
#   12171: 'NOT ENOUGH INFORMATION',
#   14751: 'SUPPORTED'},
#  {4895: 'SUPPORTED', 7344: 'SUPPORTED', 9100: 'SUPPORTED', 15865: 'SUPPORTED'},
#  {1579: 'NOT ENOUGH INFORMATION',
#   7346: 'SUPPORTED',
#   15110: 'NOT ENOUGH INFORMATION'},
#  {7352: 'SUPPORTED', 13983: 'REFUTED', 15187: 'REFUTED'},
#  {7378: 'NOT ENOUGH INFORMATION', 14229: 'NOT ENOUGH INFORMATION'},
#  {7379: 'SUPPORTED', 14597: 'SUPPORTED'},
#  {2794: 'NOT ENOUGH INFORMATION', 7384: 'REFUTED', 14684: 'REFUTED'},
#  {4950: 'REFUTED', 7424: 'REFUTED', 14892: 'REFUTED'},
#  {7431: 'REFUTED', 14079: 'NOT ENOUGH INFORMATION'},
#  {7432: 'NOT ENOUGH INFORMATION',
#   11169: 'NOT ENOUGH INFORMATION',
#   14238: 'REFUTED'},
#  {1326: 'NOT ENOUGH INFORMATION',
#   7439: 'NOT ENOUGH INFORMATION',
#   9885: 'NOT ENOUGH INFORMATION',
#   15783: 'NOT ENOUGH INFORMATION'},
#  {7445: 'SUPPORTED', 8863: 'NOT ENOUGH INFORMATION'},
#  {7451: 'REFUTED', 13202: 'REFUTED', 14731: 'REFUTED'},
#  {7509: 'SUPPORTED', 14021: 'SUPPORTED'},
#  {7512: 'NOT ENOUGH INFORMATION', 14738: 'SUPPORTED'},
#  {7521: 'SUPPORTED',
#   9724: 'SUPPORTED',
#   12650: 'SUPPORTED',
#   13589: 'SUPPORTED',
#   15053: 'SUPPORTED'},
#  {767: 'REFUTED',
#   5938: 'REFUTED',
#   7522: 'REFUTED',
#   9470: 'REFUTED',
#   11422: 'NOT ENOUGH INFORMATION',
#   16305: 'NOT ENOUGH INFORMATION'},
#  {7523: 'SUPPORTED', 16188: 'SUPPORTED'},
#  {4859: 'NOT ENOUGH INFORMATION',
#   7528: 'SUPPORTED',
#   8631: 'SUPPORTED',
#   12686: 'SUPPORTED',
#   14395: 'SUPPORTED'},
#  {7546: 'SUPPORTED', 9180: 'SUPPORTED', 9335: 'SUPPORTED'},
#  {7571: 'SUPPORTED', 11044: 'SUPPORTED'},
#  {7633: 'REFUTED', 10375: 'NOT ENOUGH INFORMATION'},
#  {7673: 'SUPPORTED', 14631: 'SUPPORTED'},
#  {7680: 'NOT ENOUGH INFORMATION',
#   11566: 'NOT ENOUGH INFORMATION',
#   15413: 'NOT ENOUGH INFORMATION'},
#  {991: 'REFUTED',
#   3428: 'REFUTED',
#   5064: 'REFUTED',
#   5936: 'REFUTED',
#   7684: 'REFUTED',
#   9477: 'REFUTED',
#   11430: 'REFUTED',
#   16158: 'SUPPORTED'},
#  {7685: 'SUPPORTED', 13740: 'SUPPORTED', 15677: 'SUPPORTED'},
#  {7728: 'NOT ENOUGH INFORMATION', 11039: 'NOT ENOUGH INFORMATION'},
#  {954: 'NOT ENOUGH INFORMATION', 7729: 'SUPPORTED', 10867: 'SUPPORTED'},
#  {2694: 'NOT ENOUGH INFORMATION',
#   7765: 'NOT ENOUGH INFORMATION',
#   14557: 'NOT ENOUGH INFORMATION'},
#  {7768: 'REFUTED', 14998: 'REFUTED'},
#  {7776: 'SUPPORTED', 16030: 'SUPPORTED'},
#  {7778: 'SUPPORTED', 12925: 'SUPPORTED', 14614: 'SUPPORTED'},
#  {7793: 'NOT ENOUGH INFORMATION', 9620: 'NOT ENOUGH INFORMATION'},
#  {948: 'SUPPORTED', 7802: 'SUPPORTED', 10086: 'SUPPORTED'},
#  {5778: 'NOT ENOUGH INFORMATION',
#   7808: 'NOT ENOUGH INFORMATION',
#   10586: 'NOT ENOUGH INFORMATION'},
#  {7840: 'SUPPORTED', 11738: 'SUPPORTED', 14076: 'NOT ENOUGH INFORMATION'},
#  {7841: 'NOT ENOUGH INFORMATION', 13439: 'REFUTED', 14683: 'REFUTED'},
#  {7842: 'SUPPORTED', 15615: 'NOT ENOUGH INFORMATION'},
#  {7845: 'SUPPORTED',
#   12189: 'SUPPORTED',
#   13454: 'SUPPORTED',
#   15919: 'NOT ENOUGH INFORMATION'},
#  {7849: 'SUPPORTED', 11591: 'SUPPORTED', 14122: 'REFUTED'},
#  {7854: 'NOT ENOUGH INFORMATION', 14526: 'NOT ENOUGH INFORMATION'},
#  {7952: 'SUPPORTED', 15011: 'SUPPORTED'},
#  {7956: 'REFUTED', 15519: 'REFUTED'},
#  {7960: 'NOT ENOUGH INFORMATION', 14094: 'NOT ENOUGH INFORMATION'},
#  {2187: 'SUPPORTED',
#   5628: 'SUPPORTED',
#   7968: 'SUPPORTED',
#   11431: 'NOT ENOUGH INFORMATION',
#   15829: 'SUPPORTED'},
#  {7971: 'REFUTED', 11198: 'REFUTED', 14963: 'SUPPORTED'},
#  {626: 'REFUTED',
#   4975: 'REFUTED',
#   7972: 'NOT ENOUGH INFORMATION',
#   9681: 'NOT ENOUGH INFORMATION',
#   14121: 'NOT ENOUGH INFORMATION'},
#  {860: 'SUPPORTED',
#   2028: 'SUPPORTED',
#   2374: 'SUPPORTED',
#   8000: 'SUPPORTED',
#   8730: 'SUPPORTED',
#   9991: 'SUPPORTED'},
#  {8024: 'NOT ENOUGH INFORMATION', 12201: 'REFUTED'},
#  {851: 'SUPPORTED',
#   8050: 'SUPPORTED',
#   11423: 'SUPPORTED',
#   15189: 'NOT ENOUGH INFORMATION'},
#  {8056: 'SUPPORTED', 11779: 'SUPPORTED', 16354: 'SUPPORTED'},
#  {8061: 'REFUTED', 16470: 'REFUTED'},
#  {3649: 'NOT ENOUGH INFORMATION',
#   8122: 'NOT ENOUGH INFORMATION',
#   13890: 'NOT ENOUGH INFORMATION'},
#  {4223: 'SUPPORTED', 8128: 'SUPPORTED', 14057: 'SUPPORTED'},
#  {8130: 'REFUTED', 11922: 'REFUTED', 14069: 'SUPPORTED'},
#  {8131: 'SUPPORTED', 11741: 'SUPPORTED', 14884: 'NOT ENOUGH INFORMATION'},
#  {1807: 'REFUTED', 8132: 'REFUTED', 14358: 'REFUTED'},
#  {3519: 'NOT ENOUGH INFORMATION', 8133: 'SUPPORTED', 14925: 'SUPPORTED'},
#  {8143: 'REFUTED', 14975: 'REFUTED'},
#  {5646: 'SUPPORTED', 8144: 'SUPPORTED', 16459: 'SUPPORTED'},
#  {8145: 'REFUTED', 15707: 'REFUTED'},
#  {8041: 'NOT ENOUGH INFORMATION',
#   8232: 'NOT ENOUGH INFORMATION',
#   14306: 'NOT ENOUGH INFORMATION'},
#  {8234: 'REFUTED', 14990: 'REFUTED'},
#  {1630: 'SUPPORTED', 8240: 'SUPPORTED', 15431: 'SUPPORTED'},
#  {3534: 'SUPPORTED',
#   8251: 'SUPPORTED',
#   13355: 'SUPPORTED',
#   14967: 'SUPPORTED'},
#  {8256: 'REFUTED', 16411: 'REFUTED'},
#  {8257: 'REFUTED', 12685: 'REFUTED', 14130: 'REFUTED'},
#  {8299: 'SUPPORTED', 12813: 'SUPPORTED'},
#  {8320: 'NOT ENOUGH INFORMATION', 15282: 'NOT ENOUGH INFORMATION'},
#  {8321: 'NOT ENOUGH INFORMATION', 15283: 'NOT ENOUGH INFORMATION'},
#  {6157: 'SUPPORTED', 8322: 'SUPPORTED', 15523: 'SUPPORTED'},
#  {8323: 'NOT ENOUGH INFORMATION', 15412: 'NOT ENOUGH INFORMATION'},
#  {8324: 'SUPPORTED', 14485: 'NOT ENOUGH INFORMATION'},
#  {5295: 'NOT ENOUGH INFORMATION',
#   8328: 'SUPPORTED',
#   10335: 'SUPPORTED',
#   14705: 'NOT ENOUGH INFORMATION'},
#  {4121: 'REFUTED',
#   8330: 'REFUTED',
#   10188: 'REFUTED',
#   12793: 'REFUTED',
#   15667: 'REFUTED'},
#  {8336: 'REFUTED', 14396: 'REFUTED'},
#  {456: 'NOT ENOUGH INFORMATION',
#   4190: 'NOT ENOUGH INFORMATION',
#   6252: 'NOT ENOUGH INFORMATION',
#   8384: 'NOT ENOUGH INFORMATION',
#   14167: 'NOT ENOUGH INFORMATION'},
#  {2674: 'NOT ENOUGH INFORMATION',
#   4677: 'NOT ENOUGH INFORMATION',
#   8386: 'NOT ENOUGH INFORMATION',
#   10314: 'NOT ENOUGH INFORMATION',
#   11735: 'NOT ENOUGH INFORMATION',
#   14558: 'NOT ENOUGH INFORMATION'},
#  {658: 'SUPPORTED',
#   4393: 'SUPPORTED',
#   8391: 'SUPPORTED',
#   11759: 'SUPPORTED',
#   13045: 'REFUTED',
#   14801: 'NOT ENOUGH INFORMATION'},
#  {8392: 'NOT ENOUGH INFORMATION',
#   12649: 'REFUTED',
#   15723: 'NOT ENOUGH INFORMATION'},
#  {8394: 'SUPPORTED', 15055: 'SUPPORTED'},
#  {7559: 'SUPPORTED', 8410: 'SUPPORTED', 10148: 'SUPPORTED'},
#  {3404: 'SUPPORTED',
#   8448: 'SUPPORTED',
#   10814: 'SUPPORTED',
#   13399: 'SUPPORTED',
#   14140: 'SUPPORTED'},
#  {3917: 'REFUTED', 8457: 'REFUTED', 15262: 'REFUTED'},
#  {8467: 'NOT ENOUGH INFORMATION', 14955: 'NOT ENOUGH INFORMATION'},
#  {3501: 'REFUTED', 8472: 'REFUTED', 11597: 'REFUTED', 15875: 'REFUTED'},
#  {8473: 'SUPPORTED', 15122: 'SUPPORTED'},
#  {8529: 'SUPPORTED', 14058: 'SUPPORTED'},
#  {6247: 'NOT ENOUGH INFORMATION',
#   8531: 'NOT ENOUGH INFORMATION',
#   15004: 'REFUTED'},
#  {8537: 'SUPPORTED', 9271: 'SUPPORTED', 15177: 'SUPPORTED'},
#  {3332: 'REFUTED', 8538: 'REFUTED', 14487: 'REFUTED'},
#  {8545: 'SUPPORTED', 11954: 'SUPPORTED', 14494: 'SUPPORTED'},
#  {497: 'SUPPORTED',
#   3827: 'SUPPORTED',
#   8546: 'SUPPORTED',
#   12338: 'SUPPORTED',
#   14950: 'SUPPORTED'},
#  {7062: 'SUPPORTED',
#   8547: 'SUPPORTED',
#   13061: 'SUPPORTED',
#   15983: 'SUPPORTED'},
#  {4907: 'SUPPORTED',
#   8548: 'SUPPORTED',
#   12510: 'SUPPORTED',
#   13610: 'SUPPORTED',
#   16167: 'SUPPORTED'},
#  {111: 'SUPPORTED',
#   4954: 'SUPPORTED',
#   8617: 'NOT ENOUGH INFORMATION',
#   13301: 'NOT ENOUGH INFORMATION',
#   14764: 'NOT ENOUGH INFORMATION'},
#  {438: 'NOT ENOUGH INFORMATION',
#   3444: 'REFUTED',
#   8622: 'REFUTED',
#   10326: 'SUPPORTED',
#   15612: 'SUPPORTED'},
#  {8623: 'SUPPORTED', 15727: 'SUPPORTED'},
#  {798: 'NOT ENOUGH INFORMATION',
#   4149: 'SUPPORTED',
#   8624: 'SUPPORTED',
#   9781: 'SUPPORTED',
#   14803: 'SUPPORTED'},
#  {8704: 'NOT ENOUGH INFORMATION', 14268: 'NOT ENOUGH INFORMATION'},
#  {8753: 'SUPPORTED', 11796: 'SUPPORTED'},
#  {8787: 'REFUTED', 14443: 'NOT ENOUGH INFORMATION'},
#  {8789: 'REFUTED', 15151: 'REFUTED'},
#  {5517: 'NOT ENOUGH INFORMATION',
#   8794: 'NOT ENOUGH INFORMATION',
#   14812: 'NOT ENOUGH INFORMATION'},
#  {8795: 'REFUTED', 16091: 'REFUTED'},
#  {7615: 'NOT ENOUGH INFORMATION', 8796: 'NOT ENOUGH INFORMATION'},
#  {5848: 'NOT ENOUGH INFORMATION',
#   8816: 'NOT ENOUGH INFORMATION',
#   10087: 'NOT ENOUGH INFORMATION'},
#  {8837: 'SUPPORTED', 13078: 'SUPPORTED'},
#  {8846: 'SUPPORTED', 14646: 'REFUTED'},
#  {6973: 'REFUTED',
#   8848: 'NOT ENOUGH INFORMATION',
#   14661: 'NOT ENOUGH INFORMATION'},
#  {1620: 'NOT ENOUGH INFORMATION',
#   4599: 'NOT ENOUGH INFORMATION',
#   8849: 'NOT ENOUGH INFORMATION',
#   15150: 'NOT ENOUGH INFORMATION'},
#  {8856: 'SUPPORTED', 16334: 'NOT ENOUGH INFORMATION'},
#  {8857: 'SUPPORTED', 14725: 'SUPPORTED'},
#  {8858: 'REFUTED', 16215: 'REFUTED'},
#  {8861: 'SUPPORTED', 16494: 'SUPPORTED'},
#  {2399: 'NOT ENOUGH INFORMATION',
#   7189: 'NOT ENOUGH INFORMATION',
#   8864: 'NOT ENOUGH INFORMATION'},
#  {7786: 'REFUTED', 8865: 'NOT ENOUGH INFORMATION'},
#  {4069: 'SUPPORTED', 8867: 'NOT ENOUGH INFORMATION'},
#  {3030: 'SUPPORTED', 8872: 'SUPPORTED'},
#  {8935: 'NOT ENOUGH INFORMATION', 13215: 'NOT ENOUGH INFORMATION'},
#  {8941: 'SUPPORTED', 14407: 'SUPPORTED'},
#  {8955: 'SUPPORTED', 12780: 'SUPPORTED', 15038: 'SUPPORTED'},
#  {8046: 'SUPPORTED',
#   8957: 'SUPPORTED',
#   13853: 'SUPPORTED',
#   14226: 'NOT ENOUGH INFORMATION'},
#  {6563: 'NOT ENOUGH INFORMATION',
#   8960: 'NOT ENOUGH INFORMATION',
#   16357: 'NOT ENOUGH INFORMATION'},
#  {4972: 'NOT ENOUGH INFORMATION',
#   8961: 'SUPPORTED',
#   16374: 'NOT ENOUGH INFORMATION'},
#  {8965: 'REFUTED', 16478: 'REFUTED'},
#  {9024: 'REFUTED', 14165: 'REFUTED'},
#  {9032: 'SUPPORTED', 15206: 'NOT ENOUGH INFORMATION'},
#  {9033: 'REFUTED', 9098: 'REFUTED', 13605: 'REFUTED', 14947: 'REFUTED'},
#  {3035: 'NOT ENOUGH INFORMATION',
#   9035: 'NOT ENOUGH INFORMATION',
#   14012: 'NOT ENOUGH INFORMATION',
#   15483: 'NOT ENOUGH INFORMATION'},
#  {9089: 'NOT ENOUGH INFORMATION', 14042: 'NOT ENOUGH INFORMATION'},
#  {9090: 'NOT ENOUGH INFORMATION', 14428: 'NOT ENOUGH INFORMATION'},
#  {9096: 'SUPPORTED',
#   11774: 'SUPPORTED',
#   13603: 'SUPPORTED',
#   15337: 'SUPPORTED'},
#  {9157: 'SUPPORTED', 14486: 'SUPPORTED'},
#  {9159: 'SUPPORTED', 14935: 'SUPPORTED'},
#  {8052: 'SUPPORTED',
#   9160: 'SUPPORTED',
#   13731: 'SUPPORTED',
#   16134: 'SUPPORTED'},
#  {9161: 'REFUTED', 11010: 'REFUTED', 13455: 'REFUTED', 14370: 'REFUTED'},
#  {9162: 'NOT ENOUGH INFORMATION', 14943: 'NOT ENOUGH INFORMATION'},
#  {9164: 'NOT ENOUGH INFORMATION', 14861: 'NOT ENOUGH INFORMATION'},
#  {9209: 'SUPPORTED', 14461: 'NOT ENOUGH INFORMATION'},
#  {9212: 'SUPPORTED', 14590: 'SUPPORTED'},
#  {1844: 'SUPPORTED', 9218: 'SUPPORTED'},
#  {5878: 'REFUTED',
#   7093: 'NOT ENOUGH INFORMATION',
#   9220: 'NOT ENOUGH INFORMATION'},
#  {9265: 'NOT ENOUGH INFORMATION',
#   12303: 'NOT ENOUGH INFORMATION',
#   14756: 'SUPPORTED'},
#  {9268: 'NOT ENOUGH INFORMATION', 14189: 'NOT ENOUGH INFORMATION'},
#  {9270: 'NOT ENOUGH INFORMATION',
#   13854: 'NOT ENOUGH INFORMATION',
#   14693: 'NOT ENOUGH INFORMATION'},
#  {879: 'SUPPORTED', 4831: 'SUPPORTED', 9273: 'SUPPORTED', 15437: 'SUPPORTED'},
#  {9277: 'NOT ENOUGH INFORMATION', 15207: 'SUPPORTED'},
#  {9280: 'NOT ENOUGH INFORMATION', 16107: 'NOT ENOUGH INFORMATION'},
#  {702: 'SUPPORTED',
#   5357: 'SUPPORTED',
#   9321: 'SUPPORTED',
#   11902: 'SUPPORTED',
#   14154: 'NOT ENOUGH INFORMATION'},
#  {9329: 'REFUTED', 13039: 'REFUTED', 14789: 'REFUTED'},
#  {9331: 'NOT ENOUGH INFORMATION', 15791: 'NOT ENOUGH INFORMATION'},
#  {9333: 'REFUTED', 15845: 'REFUTED'},
#  {9334: 'SUPPORTED', 14118: 'NOT ENOUGH INFORMATION'},
#  {9368: 'SUPPORTED', 14420: 'SUPPORTED'},
#  {3433: 'REFUTED',
#   7450: 'REFUTED',
#   9377: 'REFUTED',
#   12661: 'REFUTED',
#   13863: 'SUPPORTED',
#   15074: 'SUPPORTED'},
#  {1229: 'SUPPORTED', 9378: 'REFUTED', 15083: 'SUPPORTED'},
#  {9380: 'NOT ENOUGH INFORMATION', 14732: 'NOT ENOUGH INFORMATION'},
#  {9416: 'SUPPORTED', 16166: 'NOT ENOUGH INFORMATION'},
#  {1495: 'SUPPORTED', 3615: 'SUPPORTED', 9417: 'SUPPORTED', 16170: 'SUPPORTED'},
#  {9418: 'SUPPORTED', 15218: 'SUPPORTED'},
#  {9419: 'SUPPORTED', 15847: 'SUPPORTED'},
#  {9464: 'NOT ENOUGH INFORMATION', 14873: 'NOT ENOUGH INFORMATION'},
#  {9466: 'SUPPORTED', 15159: 'SUPPORTED'},
#  {2085: 'SUPPORTED',
#   9472: 'SUPPORTED',
#   13335: 'SUPPORTED',
#   14933: 'SUPPORTED'},
#  {9473: 'REFUTED',
#   11303: 'REFUTED',
#   11960: 'REFUTED',
#   13730: 'REFUTED',
#   14939: 'REFUTED'},
#  {8397: 'REFUTED',
#   8464: 'REFUTED',
#   9476: 'REFUTED',
#   11579: 'REFUTED',
#   14505: 'REFUTED'},
#  {8629: 'SUPPORTED', 9480: 'SUPPORTED', 15220: 'SUPPORTED'},
#  {9528: 'NOT ENOUGH INFORMATION', 14415: 'NOT ENOUGH INFORMATION'},
#  {3642: 'SUPPORTED',
#   9328: 'REFUTED',
#   9536: 'REFUTED',
#   14682: 'NOT ENOUGH INFORMATION'},
#  {9537: 'NOT ENOUGH INFORMATION',
#   13323: 'NOT ENOUGH INFORMATION',
#   13714: 'NOT ENOUGH INFORMATION',
#   13974: 'NOT ENOUGH INFORMATION',
#   15035: 'SUPPORTED'},
#  {9538: 'SUPPORTED',
#   12783: 'SUPPORTED',
#   13445: 'SUPPORTED',
#   14483: 'SUPPORTED'},
#  {9545: 'NOT ENOUGH INFORMATION', 16396: 'NOT ENOUGH INFORMATION'},
#  {3167: 'SUPPORTED', 9546: 'SUPPORTED', 15119: 'SUPPORTED'},
#  {3412: 'REFUTED',
#   5912: 'SUPPORTED',
#   9402: 'SUPPORTED',
#   9581: 'SUPPORTED',
#   11797: 'SUPPORTED'},
#  {9594: 'SUPPORTED', 13486: 'NOT ENOUGH INFORMATION'},
#  {9606: 'NOT ENOUGH INFORMATION', 14302: 'NOT ENOUGH INFORMATION'},
#  {9609: 'NOT ENOUGH INFORMATION', 14093: 'NOT ENOUGH INFORMATION'},
#  {5434: 'SUPPORTED', 9618: 'NOT ENOUGH INFORMATION'},
#  {4823: 'NOT ENOUGH INFORMATION', 9625: 'NOT ENOUGH INFORMATION'},
#  {4387: 'REFUTED', 9626: 'REFUTED'},
#  {9675: 'SUPPORTED', 14340: 'SUPPORTED'},
#  {9420: 'SUPPORTED',
#   9679: 'SUPPORTED',
#   12799: 'SUPPORTED',
#   14255: 'SUPPORTED'},
#  {9682: 'REFUTED', 16220: 'REFUTED'},
#  {9686: 'SUPPORTED', 14134: 'NOT ENOUGH INFORMATION'},
#  {9725: 'NOT ENOUGH INFORMATION', 14591: 'NOT ENOUGH INFORMATION'},
#  {9728: 'REFUTED', 16378: 'REFUTED'},
#  {9729: 'SUPPORTED', 16399: 'SUPPORTED'},
#  {9730: 'SUPPORTED', 16487: 'SUPPORTED'},
#  {9731: 'SUPPORTED', 14399: 'SUPPORTED'},
#  {1058: 'SUPPORTED',
#   9779: 'SUPPORTED',
#   13181: 'SUPPORTED',
#   14699: 'SUPPORTED'},
#  {1125: 'NOT ENOUGH INFORMATION',
#   9780: 'NOT ENOUGH INFORMATION',
#   13182: 'NOT ENOUGH INFORMATION',
#   14700: 'REFUTED'},
#  {2593: 'SUPPORTED',
#   9784: 'SUPPORTED',
#   13602: 'SUPPORTED',
#   14940: 'SUPPORTED'},
#  {2245: 'NOT ENOUGH INFORMATION', 9786: 'REFUTED', 15999: 'REFUTED'},
#  {9840: 'SUPPORTED', 14203: 'NOT ENOUGH INFORMATION'},
#  {9841: 'SUPPORTED', 15386: 'SUPPORTED'},
#  {9842: 'SUPPORTED', 14782: 'SUPPORTED'},
#  {9847: 'NOT ENOUGH INFORMATION', 15991: 'SUPPORTED'},
#  {7007: 'NOT ENOUGH INFORMATION', 9852: 'NOT ENOUGH INFORMATION'},
#  {9880: 'NOT ENOUGH INFORMATION',
#   11553: 'NOT ENOUGH INFORMATION',
#   13710: 'NOT ENOUGH INFORMATION',
#   14669: 'NOT ENOUGH INFORMATION'},
#  {9883: 'REFUTED', 13596: 'REFUTED', 14932: 'REFUTED'},
#  {2712: 'SUPPORTED',
#   6343: 'SUPPORTED',
#   9888: 'SUPPORTED',
#   12679: 'SUPPORTED',
#   14956: 'SUPPORTED'},
#  {9890: 'SUPPORTED', 15579: 'SUPPORTED'},
#  {7119: 'NOT ENOUGH INFORMATION',
#   9929: 'NOT ENOUGH INFORMATION',
#   14338: 'REFUTED'},
#  {9930: 'NOT ENOUGH INFORMATION', 15500: 'NOT ENOUGH INFORMATION'},
#  {7524: 'REFUTED', 9938: 'REFUTED', 16359: 'REFUTED'},
#  {9939: 'SUPPORTED', 15694: 'NOT ENOUGH INFORMATION'},
#  {9940: 'SUPPORTED', 14734: 'SUPPORTED'},
#  {6874: 'REFUTED', 9984: 'REFUTED', 15811: 'REFUTED'},
#  {4116: 'REFUTED',
#   7606: 'REFUTED',
#   9988: 'SUPPORTED',
#   10574: 'SUPPORTED',
#   16025: 'SUPPORTED'},
#  {10018: 'SUPPORTED', 12931: 'SUPPORTED'},
#  {10024: 'SUPPORTED', 13885: 'REFUTED'},
#  {10032: 'NOT ENOUGH INFORMATION',
#   12612: 'NOT ENOUGH INFORMATION',
#   14043: 'NOT ENOUGH INFORMATION'},
#  {10036: 'REFUTED', 12487: 'SUPPORTED', 14085: 'SUPPORTED'},
#  {3114: 'SUPPORTED', 10040: 'SUPPORTED', 15933: 'NOT ENOUGH INFORMATION'},
#  {4438: 'SUPPORTED',
#   8549: 'SUPPORTED',
#   10041: 'SUPPORTED',
#   16221: 'NOT ENOUGH INFORMATION'},
#  {10081: 'REFUTED', 14092: 'REFUTED'},
#  {125: 'SUPPORTED',
#   10082: 'SUPPORTED',
#   10139: 'SUPPORTED',
#   12496: 'SUPPORTED',
#   14102: 'SUPPORTED'},
#  {8054: 'SUPPORTED', 10083: 'REFUTED', 14508: 'NOT ENOUGH INFORMATION'},
#  {10084: 'SUPPORTED', 16407: 'SUPPORTED'},
#  {6447: 'NOT ENOUGH INFORMATION', 10088: 'NOT ENOUGH INFORMATION'},
#  {10116: 'NOT ENOUGH INFORMATION', 13077: 'REFUTED'},
#  {4331: 'SUPPORTED', 10131: 'SUPPORTED', 14429: 'SUPPORTED'},
#  {10137: 'REFUTED', 14911: 'REFUTED'},
#  {3236: 'NOT ENOUGH INFORMATION',
#   10144: 'NOT ENOUGH INFORMATION',
#   15357: 'NOT ENOUGH INFORMATION'},
#  {10145: 'SUPPORTED', 15479: 'SUPPORTED'},
#  {1106: 'SUPPORTED',
#   10146: 'SUPPORTED',
#   10355: 'SUPPORTED',
#   12021: 'NOT ENOUGH INFORMATION',
#   16072: 'NOT ENOUGH INFORMATION'},
#  {10186: 'NOT ENOUGH INFORMATION', 14095: 'NOT ENOUGH INFORMATION'},
#  {5012: 'REFUTED',
#   10187: 'NOT ENOUGH INFORMATION',
#   15182: 'NOT ENOUGH INFORMATION'},
#  {3992: 'SUPPORTED', 10248: 'SUPPORTED'},
#  {10068: 'SUPPORTED', 10273: 'SUPPORTED', 10787: 'SUPPORTED'},
#  {10282: 'SUPPORTED', 13076: 'SUPPORTED'},
#  {10305: 'REFUTED', 13671: 'REFUTED', 14414: 'REFUTED'},
#  {10315: 'SUPPORTED',
#   13295: 'SUPPORTED',
#   13821: 'SUPPORTED',
#   14067: 'SUPPORTED'},
#  {10316: 'REFUTED', 14191: 'SUPPORTED'},
#  {10320: 'SUPPORTED', 15154: 'REFUTED'},
#  {6207: 'REFUTED', 10321: 'REFUTED', 15247: 'REFUTED'},
#  {10325: 'SUPPORTED', 14471: 'NOT ENOUGH INFORMATION'},
#  {1436: 'SUPPORTED',
#   10328: 'SUPPORTED',
#   13717: 'SUPPORTED',
#   15178: 'SUPPORTED'},
#  {10329: 'SUPPORTED', 12907: 'SUPPORTED', 14484: 'SUPPORTED'},
#  {10341: 'NOT ENOUGH INFORMATION', 15815: 'NOT ENOUGH INFORMATION'},
#  {904: 'SUPPORTED',
#   3325: 'NOT ENOUGH INFORMATION',
#   6449: 'REFUTED',
#   10343: 'REFUTED',
#   11018: 'REFUTED',
#   14510: 'NOT ENOUGH INFORMATION'},
#  {10344: 'REFUTED', 13195: 'REFUTED', 15678: 'REFUTED'},
#  {10345: 'SUPPORTED', 15093: 'SUPPORTED'},
#  {10346: 'SUPPORTED', 16171: 'SUPPORTED'},
#  {10348: 'NOT ENOUGH INFORMATION', 16342: 'NOT ENOUGH INFORMATION'},
#  {10350: 'SUPPORTED', 14727: 'SUPPORTED'},
#  {10353: 'SUPPORTED', 16391: 'SUPPORTED'},
#  {10356: 'SUPPORTED', 14015: 'SUPPORTED', 15596: 'SUPPORTED'},
#  {10360: 'SUPPORTED', 16468: 'SUPPORTED'},
#  {10361: 'REFUTED', 15706: 'SUPPORTED'},
#  {7084: 'SUPPORTED', 10376: 'NOT ENOUGH INFORMATION'},
#  {6429: 'SUPPORTED', 10379: 'NOT ENOUGH INFORMATION'},
#  {3022: 'NOT ENOUGH INFORMATION', 10401: 'SUPPORTED'},
#  {10498: 'REFUTED', 12933: 'REFUTED'},
#  {10541: 'NOT ENOUGH INFORMATION', 15133: 'REFUTED'},
#  {6872: 'NOT ENOUGH INFORMATION',
#   10544: 'NOT ENOUGH INFORMATION',
#   14083: 'NOT ENOUGH INFORMATION'},
#  {3674: 'SUPPORTED', 10546: 'SUPPORTED', 15387: 'SUPPORTED'},
#  {10550: 'REFUTED', 14479: 'REFUTED'},
#  {7434: 'REFUTED',
#   9612: 'SUPPORTED',
#   10560: 'SUPPORTED',
#   12498: 'SUPPORTED',
#   15064: 'REFUTED'},
#  {2118: 'REFUTED',
#   4978: 'SUPPORTED',
#   5188: 'NOT ENOUGH INFORMATION',
#   5367: 'REFUTED',
#   5531: 'REFUTED',
#   10561: 'REFUTED',
#   10844: 'NOT ENOUGH INFORMATION',
#   13724: 'NOT ENOUGH INFORMATION',
#   15065: 'NOT ENOUGH INFORMATION'},
#  {10562: 'SUPPORTED', 15070: 'NOT ENOUGH INFORMATION'},
#  {10570: 'REFUTED', 14246: 'REFUTED'},
#  {10571: 'SUPPORTED', 16155: 'SUPPORTED'},
#  {625: 'NOT ENOUGH INFORMATION',
#   6351: 'NOT ENOUGH INFORMATION',
#   10576: 'NOT ENOUGH INFORMATION',
#   14854: 'NOT ENOUGH INFORMATION'},
#  {2451: 'SUPPORTED',
#   10578: 'NOT ENOUGH INFORMATION',
#   15886: 'NOT ENOUGH INFORMATION'},
#  {2936: 'NOT ENOUGH INFORMATION',
#   10632: 'NOT ENOUGH INFORMATION',
#   11795: 'NOT ENOUGH INFORMATION'},
#  {4044: 'SUPPORTED', 10666: 'SUPPORTED', 13474: 'SUPPORTED'},
#  {10693: 'NOT ENOUGH INFORMATION', 14197: 'NOT ENOUGH INFORMATION'},
#  {3242: 'SUPPORTED',
#   8534: 'REFUTED',
#   10322: 'REFUTED',
#   10545: 'REFUTED',
#   10694: 'REFUTED',
#   14207: 'SUPPORTED'},
#  {10696: 'NOT ENOUGH INFORMATION', 15493: 'SUPPORTED'},
#  {10697: 'SUPPORTED', 15516: 'SUPPORTED'},
#  {10698: 'SUPPORTED', 14348: 'SUPPORTED'},
#  {10706: 'SUPPORTED', 15771: 'SUPPORTED'},
#  {7687: 'NOT ENOUGH INFORMATION',
#   10714: 'NOT ENOUGH INFORMATION',
#   13198: 'NOT ENOUGH INFORMATION',
#   16207: 'NOT ENOUGH INFORMATION'},
#  {42: 'SUPPORTED', 6409: 'SUPPORTED', 10720: 'SUPPORTED'},
#  {3726: 'NOT ENOUGH INFORMATION', 10721: 'SUPPORTED'},
#  {2716: 'SUPPORTED',
#   6472: 'SUPPORTED',
#   7946: 'SUPPORTED',
#   10821: 'SUPPORTED',
#   14416: 'SUPPORTED'},
#  {10834: 'REFUTED', 15022: 'REFUTED'},
#  {10840: 'SUPPORTED',
#   12323: 'SUPPORTED',
#   13722: 'SUPPORTED',
#   15909: 'SUPPORTED'},
#  {10842: 'NOT ENOUGH INFORMATION', 15747: 'NOT ENOUGH INFORMATION'},
#  {220: 'REFUTED', 7966: 'REFUTED', 10848: 'REFUTED', 14715: 'SUPPORTED'},
#  {7382: 'SUPPORTED', 10849: 'SUPPORTED', 14601: 'SUPPORTED'},
#  {10850: 'SUPPORTED', 15454: 'REFUTED'},
#  {3388: 'REFUTED',
#   10852: 'REFUTED',
#   11021: 'SUPPORTED',
#   13613: 'REFUTED',
#   14957: 'REFUTED'},
#  {10857: 'SUPPORTED', 14124: 'SUPPORTED'},
#  {10858: 'REFUTED', 14518: 'REFUTED'},
#  {10860: 'SUPPORTED', 14126: 'SUPPORTED'},
#  {7670: 'REFUTED',
#   10983: 'SUPPORTED',
#   12168: 'SUPPORTED',
#   13676: 'NOT ENOUGH INFORMATION',
#   14421: 'NOT ENOUGH INFORMATION'},
#  {10984: 'REFUTED', 14623: 'REFUTED'},
#  {10993: 'SUPPORTED', 11154: 'SUPPORTED', 15020: 'NOT ENOUGH INFORMATION'},
#  {10999: 'REFUTED', 15623: 'REFUTED'},
# ...
#  {12007: 'NOT ENOUGH INFORMATION',
#   13871: 'NOT ENOUGH INFORMATION',
#   15477: 'NOT ENOUGH INFORMATION'},
#  {12009: 'NOT ENOUGH INFORMATION', 15478: 'NOT ENOUGH INFORMATION'},
#  {4695: 'NOT ENOUGH INFORMATION',
#   11787: 'NOT ENOUGH INFORMATION',
#   12010: 'NOT ENOUGH INFORMATION',
#   15871: 'SUPPORTED'},
#  {12011: 'SUPPORTED', 16052: 'SUPPORTED'},
#  {12012: 'SUPPORTED', 15695: 'NOT ENOUGH INFORMATION'},
#  {12017: 'SUPPORTED', 16245: 'SUPPORTED'},
#  {12019: 'REFUTED', 16397: 'REFUTED'},
#  {12020: 'SUPPORTED', 16071: 'SUPPORTED'},
#  {12022: 'SUPPORTED', 16255: 'SUPPORTED'},
#  {12025: 'SUPPORTED', 15484: 'SUPPORTED'},
#  {12026: 'REFUTED', 16404: 'REFUTED'},
#  {12027: 'SUPPORTED', 16406: 'SUPPORTED'},
#  {12030: 'SUPPORTED', 16414: 'SUPPORTED'},
#  {12040: 'SUPPORTED', 16429: 'SUPPORTED'},
#  {12044: 'REFUTED', 14525: 'REFUTED'},
#  {12045: 'NOT ENOUGH INFORMATION', 16439: 'NOT ENOUGH INFORMATION'},
#  {12055: 'SUPPORTED', 16471: 'SUPPORTED'},
#  {12056: 'SUPPORTED', 15378: 'SUPPORTED'},
#  {12057: 'SUPPORTED', 15379: 'SUPPORTED'},
#  {12058: 'NOT ENOUGH INFORMATION', 16108: 'NOT ENOUGH INFORMATION'},
#  {2029: 'SUPPORTED', 12147: 'SUPPORTED', 13887: 'SUPPORTED'},
#  {12160: 'SUPPORTED', 14148: 'NOT ENOUGH INFORMATION'},
#  {10992: 'REFUTED', 12176: 'REFUTED', 14569: 'NOT ENOUGH INFORMATION'},
#  {9095: 'NOT ENOUGH INFORMATION',
#   12177: 'NOT ENOUGH INFORMATION',
#   15254: 'NOT ENOUGH INFORMATION'},
#  {12181: 'SUPPORTED', 13846: 'SUPPORTED', 15285: 'SUPPORTED'},
#  {9882: 'NOT ENOUGH INFORMATION',
#   12185: 'NOT ENOUGH INFORMATION',
#   13858: 'NOT ENOUGH INFORMATION',
#   14927: 'NOT ENOUGH INFORMATION'},
#  {12192: 'SUPPORTED', 15799: 'NOT ENOUGH INFORMATION'},
#  {5249: 'SUPPORTED', 12193: 'SUPPORTED', 14108: 'SUPPORTED'},
#  {6679: 'REFUTED', 12202: 'NOT ENOUGH INFORMATION'},
#  {2900: 'SUPPORTED', 7271: 'SUPPORTED', 12204: 'SUPPORTED'},
#  {12296: 'SUPPORTED', 13551: 'SUPPORTED', 14622: 'SUPPORTED'},
#  {1405: 'SUPPORTED', 12304: 'SUPPORTED', 14317: 'SUPPORTED'},
#  {6676: 'SUPPORTED', 12307: 'NOT ENOUGH INFORMATION', 14447: 'SUPPORTED'},
#  {12312: 'REFUTED', 14577: 'SUPPORTED'},
#  {12313: 'NOT ENOUGH INFORMATION', 14343: 'NOT ENOUGH INFORMATION'},
#  {8621: 'NOT ENOUGH INFORMATION',
#   8851: 'NOT ENOUGH INFORMATION',
#   12314: 'SUPPORTED',
#   14219: 'SUPPORTED'},
#  {12319: 'NOT ENOUGH INFORMATION', 14231: 'NOT ENOUGH INFORMATION'},
#  {12320: 'REFUTED', 16117: 'NOT ENOUGH INFORMATION'},
#  {802: 'REFUTED',
#   9158: 'SUPPORTED',
#   11568: 'NOT ENOUGH INFORMATION',
#   12321: 'NOT ENOUGH INFORMATION',
#   15306: 'REFUTED'},
#  {1876: 'NOT ENOUGH INFORMATION',
#   5380: 'NOT ENOUGH INFORMATION',
#   12328: 'NOT ENOUGH INFORMATION',
#   14495: 'NOT ENOUGH INFORMATION'},
#  {12329: 'NOT ENOUGH INFORMATION', 16135: 'NOT ENOUGH INFORMATION'},
#  {12330: 'NOT ENOUGH INFORMATION', 15327: 'NOT ENOUGH INFORMATION'},
#  {8700: 'SUPPORTED', 12333: 'SUPPORTED', 14829: 'SUPPORTED'},
#  {12194: 'SUPPORTED', 12336: 'SUPPORTED', 15673: 'SUPPORTED'},
#  {12337: 'SUPPORTED', 15822: 'SUPPORTED'},
#  {10856: 'NOT ENOUGH INFORMATION',
#   12344: 'NOT ENOUGH INFORMATION',
#   16231: 'NOT ENOUGH INFORMATION'},
#  {7852: 'REFUTED',
#   12346: 'NOT ENOUGH INFORMATION',
#   13467: 'REFUTED',
#   14389: 'REFUTED'},
#  {7498: 'NOT ENOUGH INFORMATION', 12353: 'SUPPORTED'},
#  {3191: 'REFUTED', 12357: 'SUPPORTED'},
#  {2540: 'NOT ENOUGH INFORMATION', 12361: 'SUPPORTED'},
#  {10117: 'SUPPORTED',
#   12399: 'SUPPORTED',
#   12710: 'SUPPORTED',
#   13471: 'SUPPORTED'},
#  {9319: 'SUPPORTED',
#   12430: 'NOT ENOUGH INFORMATION',
#   13766: 'NOT ENOUGH INFORMATION'},
#  {12451: 'NOT ENOUGH INFORMATION', 14413: 'REFUTED'},
#  {282: 'SUPPORTED', 12458: 'SUPPORTED', 14630: 'SUPPORTED'},
#  {12468: 'SUPPORTED', 14308: 'SUPPORTED'},
#  {12472: 'NOT ENOUGH INFORMATION', 14759: 'NOT ENOUGH INFORMATION'},
#  {8786: 'REFUTED', 12473: 'SUPPORTED', 14066: 'REFUTED'},
#  {4005: 'SUPPORTED',
#   8235: 'SUPPORTED',
#   12481: 'SUPPORTED',
#   14199: 'SUPPORTED'},
#  {7398: 'REFUTED',
#   12483: 'NOT ENOUGH INFORMATION',
#   15156: 'NOT ENOUGH INFORMATION'},
#  {12486: 'REFUTED', 14462: 'REFUTED'},
#  {12489: 'REFUTED', 14087: 'REFUTED'},
#  {12494: 'SUPPORTED', 15911: 'SUPPORTED'},
#  {7772: 'SUPPORTED', 12499: 'SUPPORTED', 14493: 'SUPPORTED'},
#  {12504: 'NOT ENOUGH INFORMATION', 14369: 'NOT ENOUGH INFORMATION'},
#  {12506: 'SUPPORTED', 14714: 'SUPPORTED'},
#  {12513: 'NOT ENOUGH INFORMATION', 14611: 'NOT ENOUGH INFORMATION'},
#  {824: 'SUPPORTED',
#   6957: 'SUPPORTED',
#   12517: 'SUPPORTED',
#   13883: 'SUPPORTED',
#   15604: 'SUPPORTED'},
#  {7139: 'NOT ENOUGH INFORMATION', 12520: 'SUPPORTED'},
#  {6921: 'SUPPORTED',
#   9714: 'SUPPORTED',
#   12601: 'NOT ENOUGH INFORMATION',
#   14036: 'NOT ENOUGH INFORMATION'},
#  {12624: 'NOT ENOUGH INFORMATION', 14179: 'NOT ENOUGH INFORMATION'},
#  {5129: 'NOT ENOUGH INFORMATION',
#   12632: 'NOT ENOUGH INFORMATION',
#   14765: 'NOT ENOUGH INFORMATION'},
#  {9777: 'NOT ENOUGH INFORMATION',
#   12633: 'NOT ENOUGH INFORMATION',
#   14563: 'NOT ENOUGH INFORMATION'},
#  {12634: 'SUPPORTED', 14325: 'REFUTED'},
#  {8788: 'SUPPORTED', 12635: 'SUPPORTED', 15013: 'SUPPORTED'},
#  {12637: 'REFUTED', 14566: 'REFUTED'},
#  {12648: 'REFUTED', 13718: 'REFUTED', 15051: 'REFUTED'},
#  {8244: 'NOT ENOUGH INFORMATION',
#   12658: 'NOT ENOUGH INFORMATION',
#   14237: 'SUPPORTED'},
#  {5504: 'SUPPORTED', 12664: 'SUPPORTED', 14106: 'SUPPORTED'},
#  {12666: 'REFUTED', 15335: 'REFUTED'},
#  {7228: 'NOT ENOUGH INFORMATION',
#   12667: 'NOT ENOUGH INFORMATION',
#   14598: 'NOT ENOUGH INFORMATION'},
#  {12668: 'SUPPORTED', 15668: 'SUPPORTED'},
#  {12672: 'REFUTED', 15565: 'REFUTED'},
#  {10190: 'NOT ENOUGH INFORMATION', 12674: 'REFUTED', 15957: 'SUPPORTED'},
#  {12675: 'NOT ENOUGH INFORMATION', 14382: 'NOT ENOUGH INFORMATION'},
#  {3105: 'REFUTED', 12680: 'REFUTED', 15837: 'REFUTED'},
#  {8964: 'REFUTED', 12684: 'REFUTED', 14263: 'REFUTED'},
#  {6057: 'NOT ENOUGH INFORMATION', 12689: 'SUPPORTED'},
#  {12708: 'NOT ENOUGH INFORMATION', 13214: 'NOT ENOUGH INFORMATION'},
#  {4778: 'SUPPORTED', 12744: 'SUPPORTED', 14290: 'SUPPORTED'},
#  {4566: 'SUPPORTED',
#   12745: 'SUPPORTED',
#   13550: 'SUPPORTED',
#   14046: 'SUPPORTED'},
#  {6766: 'SUPPORTED',
#   12752: 'SUPPORTED',
#   13690: 'SUPPORTED',
#   14178: 'SUPPORTED'},
#  {9267: 'REFUTED',
#   12761: 'NOT ENOUGH INFORMATION',
#   15005: 'NOT ENOUGH INFORMATION'},
#  {2380: 'SUPPORTED',
#   12765: 'SUPPORTED',
#   13163: 'SUPPORTED',
#   13309: 'SUPPORTED',
#   13573: 'SUPPORTED',
#   14200: 'SUPPORTED'},
#  {12768: 'SUPPORTED', 15253: 'NOT ENOUGH INFORMATION'},
#  {12769: 'NOT ENOUGH INFORMATION', 14570: 'NOT ENOUGH INFORMATION'},
#  {7959: 'NOT ENOUGH INFORMATION',
#   11564: 'SUPPORTED',
#   12778: 'REFUTED',
#   14351: 'NOT ENOUGH INFORMATION'},
#  {12789: 'NOT ENOUGH INFORMATION', 14103: 'SUPPORTED'},
#  {6379: 'SUPPORTED', 12795: 'SUPPORTED', 15340: 'SUPPORTED'},
#  {1520: 'SUPPORTED',
#   4492: 'SUPPORTED',
#   8137: 'SUPPORTED',
#   12800: 'SUPPORTED',
#   14608: 'SUPPORTED'},
#  {1558: 'SUPPORTED',
#   4554: 'SUPPORTED',
#   8138: 'SUPPORTED',
#   12801: 'SUPPORTED',
#   14256: 'SUPPORTED'},
#  {8252: 'NOT ENOUGH INFORMATION',
#   12802: 'NOT ENOUGH INFORMATION',
#   14612: 'NOT ENOUGH INFORMATION'},
#  {6048: 'REFUTED', 12808: 'REFUTED', 14527: 'REFUTED'},
#  {7083: 'SUPPORTED', 12810: 'SUPPORTED', 14269: 'SUPPORTED'},
#  {2708: 'SUPPORTED',
#   6455: 'SUPPORTED',
#   10278: 'SUPPORTED',
#   12811: 'SUPPORTED'},
#  {9973: 'SUPPORTED', 12812: 'NOT ENOUGH INFORMATION'},
#  {12859: 'SUPPORTED', 13507: 'SUPPORTED', 14028: 'SUPPORTED'},
#  {1866: 'REFUTED',
#   2228: 'REFUTED',
#   9263: 'REFUTED',
#   12869: 'REFUTED',
#   14277: 'SUPPORTED'},
#  {7317: 'NOT ENOUGH INFORMATION',
#   12876: 'NOT ENOUGH INFORMATION',
#   14286: 'NOT ENOUGH INFORMATION'},
#  {12888: 'SUPPORTED', 14307: 'SUPPORTED'},
#  {12890: 'SUPPORTED', 14310: 'REFUTED'},
#  {8044: 'SUPPORTED',
#   12897: 'SUPPORTED',
#   13826: 'SUPPORTED',
#   14886: 'SUPPORTED'},
#  {12905: 'SUPPORTED', 14983: 'SUPPORTED'},
#  {1214: 'NOT ENOUGH INFORMATION',
#   7963: 'NOT ENOUGH INFORMATION',
#   10843: 'SUPPORTED',
#   12910: 'NOT ENOUGH INFORMATION',
#   13054: 'NOT ENOUGH INFORMATION',
#   14101: 'NOT ENOUGH INFORMATION'},
#  {12911: 'SUPPORTED', 13599: 'SUPPORTED', 14709: 'SUPPORTED'},
#  {12913: 'SUPPORTED', 15333: 'SUPPORTED'},
#  {12676: 'SUPPORTED', 12918: 'SUPPORTED', 14838: 'SUPPORTED'},
#  {6660: 'REFUTED',
#   12920: 'NOT ENOUGH INFORMATION',
#   16029: 'NOT ENOUGH INFORMATION'},
#  {5231: 'NOT ENOUGH INFORMATION', 12928: 'NOT ENOUGH INFORMATION'},
#  {10071: 'SUPPORTED', 12932: 'REFUTED'},
#  {6052: 'SUPPORTED', 12937: 'NOT ENOUGH INFORMATION'},
#  {12985: 'SUPPORTED', 13364: 'NOT ENOUGH INFORMATION', 13522: 'REFUTED'},
#  {3423: 'REFUTED',
#   9605: 'REFUTED',
#   13009: 'NOT ENOUGH INFORMATION',
#   14639: 'NOT ENOUGH INFORMATION'},
#  {6230: 'SUPPORTED',
#   10823: 'SUPPORTED',
#   13010: 'SUPPORTED',
#   14301: 'SUPPORTED'},
#  {13017: 'REFUTED', 14874: 'NOT ENOUGH INFORMATION'},
#  {13019: 'NOT ENOUGH INFORMATION', 14556: 'NOT ENOUGH INFORMATION'},
#  {13033: 'SUPPORTED', 13838: 'SUPPORTED', 14574: 'SUPPORTED'},
#  {13036: 'SUPPORTED', 15399: 'SUPPORTED'},
#  {13041: 'NOT ENOUGH INFORMATION', 14579: 'NOT ENOUGH INFORMATION'},
#  {13046: 'SUPPORTED', 16119: 'SUPPORTED'},
#  {4697: 'NOT ENOUGH INFORMATION',
#   11296: 'REFUTED',
#   13048: 'REFUTED',
#   14098: 'REFUTED'},
#  {10558: 'SUPPORTED', 13049: 'SUPPORTED', 14365: 'SUPPORTED'},
#  {13056: 'SUPPORTED', 15546: 'SUPPORTED'},
#  {2485: 'SUPPORTED',
#   7131: 'SUPPORTED',
#   10566: 'SUPPORTED',
#   13057: 'SUPPORTED',
#   14827: 'SUPPORTED'},
#  {13058: 'SUPPORTED', 14942: 'SUPPORTED'},
#  {1580: 'SUPPORTED',
#   2677: 'SUPPORTED',
#   6820: 'SUPPORTED',
#   13059: 'SUPPORTED',
#   14831: 'SUPPORTED'},
#  {13064: 'REFUTED', 16003: 'NOT ENOUGH INFORMATION'},
#  {13065: 'SUPPORTED', 15115: 'SUPPORTED'},
#  {5555: 'SUPPORTED', 10115: 'SUPPORTED', 13072: 'NOT ENOUGH INFORMATION'},
#  {11669: 'SUPPORTED', 13073: 'SUPPORTED'},
#  {9459: 'SUPPORTED', 13074: 'SUPPORTED'},
#  {6534: 'SUPPORTED', 9590: 'SUPPORTED', 13075: 'SUPPORTED'},
#  {6414: 'SUPPORTED',
#   13139: 'NOT ENOUGH INFORMATION',
#   14541: 'NOT ENOUGH INFORMATION'},
#  {3316: 'SUPPORTED',
#   8785: 'SUPPORTED',
#   13152: 'SUPPORTED',
#   14879: 'SUPPORTED'},
#  {4795: 'SUPPORTED', 13156: 'SUPPORTED', 15012: 'SUPPORTED'},
#  {13158: 'REFUTED', 15134: 'REFUTED'},
#  {5720: 'REFUTED',
#   8618: 'REFUTED',
#   10989: 'REFUTED',
#   13160: 'REFUTED',
#   14766: 'REFUTED'},
#  {13165: 'REFUTED', 14454: 'REFUTED'},
#  {10323: 'SUPPORTED', 13168: 'SUPPORTED', 15019: 'REFUTED'},
#  {11155: 'REFUTED', 13169: 'NOT ENOUGH INFORMATION', 15268: 'REFUTED'},
#  {11418: 'NOT ENOUGH INFORMATION',
#   13176: 'NOT ENOUGH INFORMATION',
#   15167: 'NOT ENOUGH INFORMATION'},
#  {6567: 'SUPPORTED',
#   9932: 'SUPPORTED',
#   13177: 'NOT ENOUGH INFORMATION',
#   15036: 'NOT ENOUGH INFORMATION'},
#  {159: 'SUPPORTED', 9778: 'SUPPORTED', 13178: 'SUPPORTED', 14221: 'SUPPORTED'},
#  {3910: 'NOT ENOUGH INFORMATION',
#   13180: 'NOT ENOUGH INFORMATION',
#   14588: 'NOT ENOUGH INFORMATION'},
#  {2185: 'SUPPORTED',
#   8958: 'SUPPORTED',
#   13184: 'NOT ENOUGH INFORMATION',
#   14814: 'NOT ENOUGH INFORMATION'},
#  {1862: 'SUPPORTED',
#   3513: 'NOT ENOUGH INFORMATION',
#   9613: 'NOT ENOUGH INFORMATION',
#   13186: 'NOT ENOUGH INFORMATION',
#   15196: 'NOT ENOUGH INFORMATION'},
#  {13188: 'SUPPORTED', 15925: 'REFUTED'},
#  {13190: 'SUPPORTED', 14374: 'SUPPORTED'},
#  {10569: 'REFUTED', 11580: 'REFUTED', 13192: 'REFUTED', 15955: 'REFUTED'},
#  {1839: 'REFUTED',
#   8465: 'REFUTED',
#   11989: 'REFUTED',
#   13196: 'REFUTED',
#   15092: 'NOT ENOUGH INFORMATION'},
#  {13200: 'SUPPORTED', 14847: 'SUPPORTED'},
#  {13201: 'SUPPORTED', 16237: 'REFUTED'},
#  {12702: 'SUPPORTED', 13205: 'SUPPORTED'},
#  {10500: 'REFUTED', 13208: 'REFUTED'},
#  {10501: 'SUPPORTED', 13209: 'SUPPORTED'},
#  {11494: 'REFUTED', 13210: 'REFUTED'},
#  {1456: 'SUPPORTED',
#   5539: 'SUPPORTED',
#   11913: 'SUPPORTED',
#   13283: 'SUPPORTED',
#   14633: 'SUPPORTED'},
#  {8947: 'SUPPORTED',
#   9879: 'SUPPORTED',
#   13297: 'NOT ENOUGH INFORMATION',
#   14068: 'NOT ENOUGH INFORMATION'},
#  {10829: 'SUPPORTED', 13304: 'SUPPORTED', 14655: 'SUPPORTED'},
#  {9532: 'SUPPORTED', 13305: 'SUPPORTED', 14326: 'SUPPORTED'},
#  {13313: 'SUPPORTED', 14335: 'SUPPORTED'},
#  {13314: 'REFUTED', 15390: 'NOT ENOUGH INFORMATION'},
#  {9029: 'REFUTED', 10327: 'REFUTED', 13329: 'SUPPORTED', 14915: 'SUPPORTED'},
#  {13330: 'REFUTED', 15175: 'REFUTED'},
#  {9884: 'SUPPORTED', 13336: 'SUPPORTED', 14818: 'SUPPORTED'},
#  {8627: 'SUPPORTED', 13339: 'SUPPORTED', 15774: 'SUPPORTED'},
#  {13344: 'SUPPORTED', 15089: 'SUPPORTED'},
#  {3086: 'SUPPORTED',
#   13346: 'NOT ENOUGH INFORMATION',
#   15572: 'NOT ENOUGH INFORMATION'},
#  {13347: 'SUPPORTED', 15574: 'SUPPORTED'},
#  {13350: 'NOT ENOUGH INFORMATION', 14607: 'NOT ENOUGH INFORMATION'},
#  {13352: 'NOT ENOUGH INFORMATION', 16198: 'NOT ENOUGH INFORMATION'},
#  {13353: 'SUPPORTED', 16214: 'SUPPORTED'},
#  {13360: 'SUPPORTED', 16095: 'SUPPORTED'},
#  {13361: 'SUPPORTED', 14860: 'SUPPORTED'},
#  {13425: 'SUPPORTED', 14636: 'SUPPORTED'},
#  {4062: 'NOT ENOUGH INFORMATION',
#   13440: 'NOT ENOUGH INFORMATION',
#   15165: 'NOT ENOUGH INFORMATION'},
#  {9933: 'SUPPORTED', 13448: 'NOT ENOUGH INFORMATION', 16122: 'SUPPORTED'},
#  {9677: 'SUPPORTED', 13450: 'SUPPORTED', 14815: 'SUPPORTED'},
#  {13457: 'SUPPORTED', 14941: 'SUPPORTED'},
#  {1826: 'SUPPORTED', 13464: 'REFUTED', 15363: 'REFUTED'},
#  {5783: 'NOT ENOUGH INFORMATION', 13465: 'SUPPORTED'},
#  {11199: 'NOT ENOUGH INFORMATION',
#   13469: 'NOT ENOUGH INFORMATION',
#   14974: 'NOT ENOUGH INFORMATION'},
#  {5281: 'NOT ENOUGH INFORMATION', 13472: 'SUPPORTED'},
#  {9519: 'NOT ENOUGH INFORMATION', 13476: 'NOT ENOUGH INFORMATION'},
#  {9143: 'SUPPORTED',
#   11118: 'SUPPORTED',
#   11261: 'SUPPORTED',
#   13480: 'SUPPORTED'},
#  {10508: 'SUPPORTED', 13483: 'SUPPORTED'},
#  {13544: 'NOT ENOUGH INFORMATION', 14419: 'NOT ENOUGH INFORMATION'},
#  {3673: 'REFUTED',
#   7371: 'REFUTED',
#   9720: 'REFUTED',
#   13570: 'NOT ENOUGH INFORMATION',
#   14445: 'NOT ENOUGH INFORMATION'},
#  {13576: 'NOT ENOUGH INFORMATION', 14772: 'NOT ENOUGH INFORMATION'},
#  {13577: 'SUPPORTED', 15381: 'SUPPORTED'},
#  {13578: 'NOT ENOUGH INFORMATION', 14780: 'NOT ENOUGH INFORMATION'},
#  {13584: 'REFUTED', 15410: 'REFUTED'},
#  {5253: 'SUPPORTED',
#   8853: 'NOT ENOUGH INFORMATION',
#   13592: 'NOT ENOUGH INFORMATION',
#   14100: 'NOT ENOUGH INFORMATION'},
#  {9539: 'SUPPORTED',
#   12492: 'SUPPORTED',
#   13593: 'SUPPORTED',
#   14491: 'SUPPORTED'},
#  {13600: 'SUPPORTED', 15197: 'SUPPORTED'},
#  {545: 'SUPPORTED',
#   9474: 'NOT ENOUGH INFORMATION',
#   12331: 'NOT ENOUGH INFORMATION',
#   13601: 'NOT ENOUGH INFORMATION',
#   14501: 'NOT ENOUGH INFORMATION'},
#  {3870: 'SUPPORTED',
#   9846: 'SUPPORTED',
#   13609: 'SUPPORTED',
#   15989: 'SUPPORTED'},
#  {9421: 'REFUTED',
#   13616: 'NOT ENOUGH INFORMATION',
#   14964: 'NOT ENOUGH INFORMATION'},
#  {4707: 'NOT ENOUGH INFORMATION',
#   13617: 'NOT ENOUGH INFORMATION',
#   15107: 'SUPPORTED'},
#  {13619: 'REFUTED', 16211: 'NOT ENOUGH INFORMATION'},
#  {13621: 'SUPPORTED', 16246: 'SUPPORTED'},
#  {13624: 'SUPPORTED', 16266: 'SUPPORTED'},
#  {10042: 'NOT ENOUGH INFORMATION',
#   12347: 'NOT ENOUGH INFORMATION',
#   13625: 'NOT ENOUGH INFORMATION',
#   16078: 'SUPPORTED'},
#  {13629: 'NOT ENOUGH INFORMATION', 15125: 'NOT ENOUGH INFORMATION'},
#  {268: 'SUPPORTED',
#   1731: 'SUPPORTED',
#   6770: 'SUPPORTED',
#   12350: 'SUPPORTED',
#   13630: 'SUPPORTED',
#   14397: 'SUPPORTED'},
#  {7590: 'SUPPORTED', 13632: 'SUPPORTED'},
#  {12422: 'SUPPORTED', 13633: 'SUPPORTED'},
#  {9366: 'NOT ENOUGH INFORMATION', 13635: 'SUPPORTED'},
#  {4870: 'NOT ENOUGH INFORMATION', 13638: 'SUPPORTED'},
#  {11266: 'SUPPORTED', 13640: 'SUPPORTED'},
#  {12153: 'REFUTED', 13649: 'REFUTED', 14031: 'REFUTED'},
#  {13665: 'NOT ENOUGH INFORMATION', 14038: 'NOT ENOUGH INFORMATION'},
#  {10981: 'SUPPORTED', 13675: 'SUPPORTED', 14156: 'SUPPORTED'},
#  {2790: 'REFUTED', 8388: 'REFUTED', 13712: 'REFUTED', 14900: 'REFUTED'},
#  {13721: 'NOT ENOUGH INFORMATION', 14924: 'NOT ENOUGH INFORMATION'},
#  {5200: 'SUPPORTED',
#   9414: 'SUPPORTED',
#   11172: 'SUPPORTED',
#   13729: 'SUPPORTED',
#   15920: 'SUPPORTED'},
#  {13744: 'NOT ENOUGH INFORMATION', 16351: 'SUPPORTED'},
#  {6991: 'NOT ENOUGH INFORMATION',
#   11023: 'NOT ENOUGH INFORMATION',
#   13746: 'NOT ENOUGH INFORMATION',
#   15103: 'NOT ENOUGH INFORMATION'},
#  {8335: 'SUPPORTED',
#   10855: 'SUPPORTED',
#   13752: 'SUPPORTED',
#   15867: 'NOT ENOUGH INFORMATION'},
#  {13754: 'NOT ENOUGH INFORMATION', 16254: 'NOT ENOUGH INFORMATION'},
#  ...]

# %%
## Generated answers of all models.

filenames = ['llama33-70b_answers.txt',
 'mistral-24b_answers.txt',
 'gpt4o-mini_answers.txt',
 'qwen25-7b_answers.txt',
 'deepsek-v3_answers.txt',
 'olmo_gguf_answers_13b.txt',
 ]

filenames = ["GeneratedAnswers/"+f for f in filenames]

# %% [markdown]
# ### Get MedRevQA (full dataset) scores

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

## Get final evaluation scores of the predicted LLM answers

def get_predictions(filename, label_type):
    with open(filename, "r", encoding="utf-8") as f:
        lines = f.readlines()
        
    if "olmo" in filename:
        lines = lines[1::3]
    
    # Get all the predicted labels on the entire dataset MedRevQA
    llm_predicted_labels = list()
    for line in lines:
        if "SUPPORTED" in line:
            llm_predicted_labels.append("SUPPORTED")
        elif "REFUTED" in line:
            llm_predicted_labels.append("REFUTED")
        elif "NOT ENOUGH INFORMATION" in line:
            llm_predicted_labels.append("NOT ENOUGH INFORMATION")
        else:
            llm_predicted_labels.append("NOT ENOUGH INFORMATION")
        

    # Get the full dataset predictions
    llm_predicted_medrevqa = np.array(llm_predicted_labels)

    mapper = {"SUPPORTED": 0, "REFUTED": 2, "NOT ENOUGH INFORMATION": 1}
    predicted_labels = list()
    gold_labels = list()

    for label in llm_predicted_medrevqa:
        predicted_labels.append(mapper[label])

    # Take all the labels (16501)
    for label in labels:
        gold_labels.append(mapper[label])
    

    # Make predictions
    y_pred = np.array(predicted_labels)
    y_test = np.array(gold_labels)

    # Calculate precision, recall, and F1 score with macro averaging
    precision_macro = precision_score(y_test, y_pred, average='macro')
    recall_macro = recall_score(y_test, y_pred, average='macro')
    f1_macro = f1_score(y_test, y_pred, average='macro')

    ## get precision, recall, f1, accuracy rounded to 4 decimal places

    print(f"Precision: {precision_macro:.4f} | Recall: {recall_macro:.4f} | F1: {f1_macro:.4f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")


for filename in filenames:
    print(f"Results for {filename} (full dataset):")
    get_predictions(filename, label_type="NEWEST")
    print()
# Out:
# Results for GeneratedAnswers/llama33-70b_answers.txt (full dataset):
# Precision: 0.5275 | Recall: 0.4591 | F1: 0.3934
# Accuracy: 0.4661
#
# Results for GeneratedAnswers/mistral-24b_answers.txt (full dataset):
# Precision: 0.5060 | Recall: 0.4628 | F1: 0.4568
# Accuracy: 0.5192
#
# Results for GeneratedAnswers/gpt4o-mini_answers.txt (full dataset):
# Precision: 0.5263 | Recall: 0.4513 | F1: 0.4293
# Accuracy: 0.5211
#
# Results for GeneratedAnswers/qwen25-7b_answers.txt (full dataset):
# Precision: 0.4640 | Recall: 0.4235 | F1: 0.3875
# Accuracy: 0.4569
#
# Results for GeneratedAnswers/deepsek-v3_answers.txt (full dataset):
# Precision: 0.5617 | Recall: 0.4622 | F1: 0.4380
# Accuracy: 0.5409
#
# Results for GeneratedAnswers/olmo_gguf_answers_13b.txt (full dataset):
# Precision: 0.4347 | Recall: 0.4247 | F1: 0.3790
# Accuracy: 0.4316

# %% [markdown]
# ### Get MedChangeQA results (changed knowledge subset)

# %%
## Get all the labels of MedChangeQA

final_labels = list()
final_keys = list()
outdated_keys = list()
outdated_labels = list()  
newest_labels = list()   
newest_keys = list()

for verdict_dict in verdict_map:
    final_label = verdict_dict[list(verdict_dict.keys())[0]]
    final_labels.append(final_label)
    final_keys.append(list(verdict_dict.keys())[0])

    verdict_changed = False
    for key in verdict_dict.keys():
        if verdict_dict[key] != final_label:

            outdated_keys.append(key)
            outdated_labels.append(verdict_dict[key])

            newest_labels.append(verdict_dict[list(verdict_dict.keys())[0]])
            newest_keys.append(list(verdict_dict.keys())[0])

            verdict_changed = True
            break

# MedChangeQA is a subset where 512 questions changed their verdict over time
len(final_labels), len(newest_labels)
# Out:
# (1535, 512)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

## Get final evaluation scores of the predicted LLM answers

def get_predictions_2(filename, label_type):
    #CHANGE
    global outdated_keys, outdated_labels, newest_labels
    with open(filename, "r", encoding="utf-8") as f:
        #print('Its been open')
        lines = f.readlines()
        
    #if "biomistral" in filename or "pmcllama" in filename:
        #print('split lines because biomistral')
        #lines = lines[1::3]
    #print(f'len lines:{len(lines)}')
    # Get all the predicted labels on the entire dataset MedRevQA
    llm_predicted_labels = list()
    for line in lines:
        if "SUPPORTED" in line:
            llm_predicted_labels.append("SUPPORTED")
        elif "REFUTED" in line:
            llm_predicted_labels.append("REFUTED")
        elif "NOT ENOUGH INFORMATION" in line:
            llm_predicted_labels.append("NOT ENOUGH INFORMATION")
        
    #print(f'len predicted labels: {len(llm_predicted_labels)}')
    #print(f'len outdated keys: {len(outdated_keys)}')
    # Get only the changed-knowledge subset (MedChangeQA) #THIS IS THE PROBLEM
    

    #print(f"len(llm_predicted_labels): {len(llm_predicted_labels)}")
    ##print(f"max(outdated_keys): {max(outdated_keys)}")
    #print(f"len(outdated_keys): {len(outdated_keys)}")

#   CHANGE
    #llm_predicted_medchange = np.array(llm_predicted_labels)[np.array(outdated_keys)]
    # Convert
    llm_predicted_labels = np.array(llm_predicted_labels)
    outdated_keys = np.array(outdated_keys)

    # Filter
    valid_keys = outdated_keys[outdated_keys < len(llm_predicted_labels)]
    if len(valid_keys) < len(outdated_keys):
        print(f" {len(outdated_keys) - len(valid_keys)} INDEX PROBLEM")

    
    llm_predicted_medchange = llm_predicted_labels[valid_keys]



    mapper = {"SUPPORTED": 0, "REFUTED": 2, "NOT ENOUGH INFORMATION": 1}
    predicted_labels = list()
    gold_labels = list()

    for label in llm_predicted_medchange:
        predicted_labels.append(mapper[label])

    # One experiment uses outdated labels as gold labels, another one uses newest (latest) labels
    if label_type == "OUTDATED":
        for label in outdated_labels:
            gold_labels.append(mapper[label])
    elif label_type == "NEWEST":
        for label in newest_labels:
            gold_labels.append(mapper[label])

    # Make predictions
    y_pred = np.array(predicted_labels)
    y_test = np.array(gold_labels)

    #CHANGE
    if len(y_pred) != len(y_test):
        min_len = min(len(y_pred), len(y_test))
        print(f"ADJUST: y_pred={len(y_pred)}, y_test={len(y_test)} → {min_len}")
        y_pred = y_pred[:min_len]
        y_test = y_test[:min_len]

    # Calculate precision, recall, and F1 score with macro averaging
    precision_macro = precision_score(y_test, y_pred, average='macro')
    recall_macro = recall_score(y_test, y_pred, average='macro')
    f1_macro = f1_score(y_test, y_pred, average='macro')

    ## get precision, recall, f1, accuracy rounded to 4 decimal places

    print(f"Precision: {precision_macro:.4f} | Recall: {recall_macro:.4f} | F1: {f1_macro:.4f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

    return f1_macro

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

## Get final evaluation scores of the predicted LLM answers

def get_predictions_original(filename, label_type):
    with open(filename, "r", encoding="utf-8") as f:
        lines = f.readlines()
        
    if "biomistral" in filename or "pmcllama" in filename:
        lines = lines[1::3]
    
    # Get all the predicted labels on the entire dataset MedRevQA
    llm_predicted_labels = list()
    for line in lines:
        if "SUPPORTED" in line:
            llm_predicted_labels.append("SUPPORTED")
        elif "REFUTED" in line:
            llm_predicted_labels.append("REFUTED")
        elif "NOT ENOUGH INFORMATION" in line:
            llm_predicted_labels.append("NOT ENOUGH INFORMATION")
        

    # Get only the changed-knowledge subset (MedChangeQA)
    llm_predicted_medchange = np.array(llm_predicted_labels)[np.array(outdated_keys)]

    mapper = {"SUPPORTED": 0, "REFUTED": 2, "NOT ENOUGH INFORMATION": 1}
    predicted_labels = list()
    gold_labels = list()

    for label in llm_predicted_medchange:
        predicted_labels.append(mapper[label])

    # One experiment uses outdated labels as gold labels, another one uses newest (latest) labels
    if label_type == "OUTDATED":
        for label in outdated_labels:
            gold_labels.append(mapper[label])
    elif label_type == "NEWEST":
        for label in newest_labels:
            gold_labels.append(mapper[label])

    # Make predictions
    y_pred = np.array(predicted_labels)
    y_test = np.array(gold_labels)

    # Calculate precision, recall, and F1 score with macro averaging
    precision_macro = precision_score(y_test, y_pred, average='macro')
    recall_macro = recall_score(y_test, y_pred, average='macro')
    f1_macro = f1_score(y_test, y_pred, average='macro')

    ## get precision, recall, f1, accuracy rounded to 4 decimal places

    print(f"Precision: {precision_macro:.4f} | Recall: {recall_macro:.4f} | F1: {f1_macro:.4f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    return f1_macro

# %%
print("QWEN ORIGINAL")
print("Latest")
f1_latest = get_predictions_original('GeneratedAnswers/qwen25-7b_answers.txt', label_type='NEWEST')
print("Outdated")
f1_outdated = get_predictions_original('GeneratedAnswers/qwen25-7b_answers.txt', label_type='OUTDATED')
print(f"F1 diff: {(f1_latest - f1_outdated)*100}")

print("QWEN MODIFIED")
print("Latest")
f1_latest = get_predictions_2('GeneratedAnswers/qwen25-7b_answers.txt', label_type='NEWEST')
print("Outdated")
f1_outdated = get_predictions_2('GeneratedAnswers/qwen25-7b_answers.txt', label_type='OUTDATED')
print(f"F1 diff: {(f1_latest - f1_outdated)*100}")
# Out:
# QWEN ORIGINAL
# Latest
# Precision: 0.2712 | Recall: 0.3082 | F1: 0.2602
# Accuracy: 0.3730
# Outdated
# Precision: 0.4262 | Recall: 0.3711 | F1: 0.3076
# Accuracy: 0.3535
# F1 diff: -4.739933696312237
# QWEN MODIFIED
# Latest
# Precision: 0.2712 | Recall: 0.3082 | F1: 0.2602
# Accuracy: 0.3730
# Outdated
# Precision: 0.4262 | Recall: 0.3711 | F1: 0.3076
# Accuracy: 0.3535
# F1 diff: -4.739933696312237

# %%
print("BIOMISTRAL MODIFIED")
print("Latest")
f1_latest = get_predictions_2('GeneratedAnswers/biomistral_answers.txt', label_type='NEWEST')
print("Outdated")
f1_outdated = get_predictions_2('GeneratedAnswers/biomistral_answers.txt', label_type='OUTDATED')
print(f"F1 diff: {(f1_latest - f1_outdated)*100}")

print("BIOMISTRAL ORIGINAL")
print("Latest")
get_predictions_original('GeneratedAnswers/biomistral_answers.txt', label_type='NEWEST')
print("Outdated")
get_predictions_original('GeneratedAnswers/biomistral_answers.txt', label_type='OUTDATED')
# Out:
# BIOMISTRAL MODIFIED
# Latest
#  67 INDEX PROBLEM
# ADJUST: y_pred=445, y_test=512 → 445
# Precision: 0.3063 | Recall: 0.3031 | F1: 0.3028
# Accuracy: 0.3146
# Outdated
#  67 INDEX PROBLEM
# ADJUST: y_pred=445, y_test=512 → 445
# Precision: 0.3670 | Recall: 0.3641 | F1: 0.3576
# Accuracy: 0.3685
# F1 diff: -5.486144815072108
# BIOMISTRAL ORIGINAL
# Latest
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 10
#       8 print("BIOMISTRAL ORIGINAL")
#       9 print("Latest")
# ---> 10 get_predictions_original('GeneratedAnswers/biomistral_answers.txt', label_type='NEWEST')
#      11 print("Outdated")
#      12 get_predictions_original('GeneratedAnswers/biomistral_answers.txt', label_type='OUTDATED')
#
# Cell In[39], line 24, in get_predictions_original(filename, label_type)
#      20         llm_predicted_labels.append("NOT ENOUGH INFORMATION")
#      23 # Get only the changed-knowledge subset (MedChangeQA)
# ---> 24 llm_predicted_medchange = np.array(llm_predicted_labels)[np.array(outdated_keys)]
#      26 mapper = {"SUPPORTED": 0, "REFUTED": 2, "NOT ENOUGH INFORMATION": 1}
#      27 predicted_labels = list()
#
# IndexError: index 15785 is out of bounds for axis 0 with size 15613

# %%
# Get scores using outdated labels
for filename in filenames:
    print(f"Results for {filename}:")
    get_predictions(filename, label_type="OUTDATED")
    print()
# Out:
# Results for GeneratedAnswers/llama33-70b_answers.txt:
# Precision: 0.5275 | Recall: 0.4591 | F1: 0.3934
# Accuracy: 0.4661
#
# Results for GeneratedAnswers/mistral-24b_answers.txt:
# Precision: 0.5060 | Recall: 0.4628 | F1: 0.4568
# Accuracy: 0.5192
#
# Results for GeneratedAnswers/gpt4o-mini_answers.txt:
# Precision: 0.5263 | Recall: 0.4513 | F1: 0.4293
# Accuracy: 0.5211
#
# Results for GeneratedAnswers/qwen25-7b_answers.txt:
# Precision: 0.4640 | Recall: 0.4235 | F1: 0.3875
# Accuracy: 0.4569
#
# Results for GeneratedAnswers/deepsek-v3_answers.txt:
# Precision: 0.5617 | Recall: 0.4622 | F1: 0.4380
# Accuracy: 0.5409
#
# Results for GeneratedAnswers/olmo_gguf_answers_13b.txt:
# Precision: 0.4347 | Recall: 0.4247 | F1: 0.3790
# Accuracy: 0.4316

# %%
# Get scores using newest labels
for filename in filenames:
    print(f"Results for {filename} (newest labels):")
    get_predictions(filename, label_type="NEWEST")
    print()
# Out:
# Results for GeneratedAnswers/llama33-70b_answers.txt (newest labels):
# Precision: 0.5275 | Recall: 0.4591 | F1: 0.3934
# Accuracy: 0.4661
#
# Results for GeneratedAnswers/mistral-24b_answers.txt (newest labels):
# Precision: 0.5060 | Recall: 0.4628 | F1: 0.4568
# Accuracy: 0.5192
#
# Results for GeneratedAnswers/gpt4o-mini_answers.txt (newest labels):
# Precision: 0.5263 | Recall: 0.4513 | F1: 0.4293
# Accuracy: 0.5211
#
# Results for GeneratedAnswers/qwen25-7b_answers.txt (newest labels):
# Precision: 0.4640 | Recall: 0.4235 | F1: 0.3875
# Accuracy: 0.4569
#
# Results for GeneratedAnswers/deepsek-v3_answers.txt (newest labels):
# Precision: 0.5617 | Recall: 0.4622 | F1: 0.4380
# Accuracy: 0.5409
#
# Results for GeneratedAnswers/olmo_gguf_answers_13b.txt (newest labels):
# Precision: 0.4347 | Recall: 0.4247 | F1: 0.3790
# Accuracy: 0.4316

# %% [markdown]
# ### Get n-gram counts over the years

# %%
import requests

payload = {
    'index': 'v4_dolma-v1_7_llama',
    'query_type': 'count',
    'query': 'Cochrane Database of Systematic Reviews',
}

## Use the infi-gram API to get n-gram counts over the years
result = requests.post('https://api.infini-gram.io/', json=payload).json()
print(result)

#df = pd.read_csv("./FullQA.csv", index_col=0) CHANGED
df = pd.read_csv("./FullScraped.csv", index_col=0)
titles = df.title.tolist()

changed_titles = np.array(titles)[np.array(outdated_keys)]
changed_titles = [c[:-1] for c in changed_titles]
changed_titles = [c.replace("?", "") for c in changed_titles]
changed_titles = [c.replace("  ", " ") for c in changed_titles]
changed_titles = [c.replace("   ", " ") for c in changed_titles]
changed_titles
# Out:
# {'approx': False, 'count': 120392, 'latency': 0.6556510925292969, 'token_ids': [315, 2878, 10800, 5470, 310, 2184, 2454, 830, 7406], 'tokens': ['▁C', 'och', 'rane', '▁Database', '▁of', '▁System', 'atic', '▁Re', 'views']}
# ['Cranberries for preventing urinary tract infections',
#  'Oral contraceptive pill for primary dysmenorrhoea',
#  'Nasal intermittent positive pressure ventilation (NIPPV) versus nasal continuous positive airway pressure (NCPAP) for preterm neonates after extubation',
#  'Mechanical methods for induction of labour',
#  'Interventions for acute non-arteritic central retinal artery occlusion',
#  'Antibody tests for identification of current and past infection with SARS-CoV-2',
#  'Surgical interventions for bilateral congenital cataract',
#  'Water for wound cleansing',
#  'Physical training for cystic fibrosis',
#  'Late (> 7 days) systemic postnatal corticosteroids for prevention of bronchopulmonary dysplasia in preterm infants',
#  'Prophylactic antibiotics for preventing Gram positive infections associated with long-term central venous catheters in oncology patients',
#  'Interventions for intermittent exotropia',
#  'Nocturnal non-invasive positive pressure ventilation for stable chronic obstructive pulmonary disease',
#  'Non-specialist health worker interventions for mental health care in low- and middle- income countries',
#  'Single versus double intrauterine insemination (IUI) in stimulated cycles for subfertile couples',
#  'Convalescent plasma or hyperimmune immunoglobulin for people with COVID-19: a living systematic review',
#  'Gastro-oesophageal reflux treatment for asthma in adults and children',
#  'Surgery or embolisation for varicoceles in subfertile men',
#  'Rapid, point-of-care antigen and molecular-based tests for diagnosis of SARS-CoV-2 infection',
#  'Zinc supplementation for improving pregnancy and infant outcome',
#  'Prophylactic antibiotics for preventing pneumococcal infection in children with sickle cell disease',
#  'High versus low medium chain triglyceride content of formula for promoting short term growth of preterm infants',
#  'Sphincterotomy for biliary sphincter of Oddi dysfunction',
#  'Ketogenic diet and other dietary treatments for epilepsy',
#  'Antibiotic prophylaxis for hernia repair',
#  'Interventions for treating oral lichen planus',
#  'Intravenous immunoglobulin for suspected or subsequently proven infection in neonates',
#  'Tonsillectomy for periodic fever, aphthous stomatitis, pharyngitis and cervical adenitis syndrome (PFAPA)',
#  'Laparoscopic colposuspension for urinary incontinence in women',
#  'Progestogen for preventing miscarriage',
#  'Malaria chemoprophylaxis in sickle cell disease',
#  'Interventions for replacing missing teeth: different types of dental implants',
#  'Tai chi for treating rheumatoid arthritis',
#  'Oral non-steroidal anti-inflammatory drug therapy for cystic fibrosis',
#  'Once daily versus multiple daily dosing with intravenous aminoglycosides for cystic fibrosis',
#  'Endometrial resection and ablation versus hysterectomy for heavy menstrual bleeding',
#  'Formula milk versus maternal breast milk for feeding preterm or low birth weight infants',
#  'Inositol in preterm infants at risk for or having respiratory distress syndrome',
#  'Antidepressant and benzodiazepine for major depression',
#  'Guided tissue regeneration for periodontal infra-bony defects',
#  'Long-term antibiotics for preventing recurrent urinary tract infection in children',
#  'Interventions for dysphagia and nutritional support in acute and subacute stroke',
#  'Antibiotics for exacerbations of chronic obstructive pulmonary disease',
#  'Carbamazepine versus phenobarbitone monotherapy for epilepsy',
#  'Interventionist versus expectant care for severe pre-eclampsia before term',
#  'Nebulised hypertonic saline for cystic fibrosis',
#  'Antibiotics for treating scrub typhus',
#  'Antidepressants for treating depression in dementia',
#  'Red blood cell transfusion to treat or prevent complications in sickle cell disease: an overview of Cochrane reviews',
#  'Communication skills training for healthcare professionals working with people who have cancer',
#  'Prophylactic vaccination against human papillomaviruses to prevent cervical cancer and its precursors',
#  "Enteral nutritional therapy for induction of remission in Crohn's disease",
#  'Immunoglobulin infusion for isoimmune haemolytic jaundice in neonates',
#  'Serotonin and noradrenaline reuptake inhibitors (SNRIs) for fibromyalgia syndrome',
#  'Neuroleptic reduction and/or cessation and neuroleptics as specific treatments for tardive dyskinesia',
#  'Pelvic floor muscle training for prevention and treatment of urinary and faecal incontinence in antenatal and postnatal women',
#  'Feed thickener for newborn infants with gastro-oesophageal reflux',
#  'Corticosteroids for chronic inflammatory demyelinating polyradiculoneuropathy',
#  'Zuclopenthixol dihydrochloride for schizophrenia',
#  'Electrical cardioversion for atrial fibrillation and flutter',
#  'Patient education in the management of coronary heart disease',
#  'Hospital at home versus in-patient hospital care',
#  'Topical analgesics for acute and chronic pain in adults',
#  'Nerve blocks (subcostal, lateral cutaneous, femoral, triple, psoas) for hip fractures',
#  'Carbamazepine versus phenytoin monotherapy for epilepsy: an individual participant data review',
#  'Buprenorphine for the management of opioid withdrawal',
#  "Vitamin E for Alzheimer's disease",
#  'Nutritional supplementation for hip fracture aftercare in older people',
#  'Follow-up strategies for patients treated for non-metastatic colorectal cancer',
#  'Infant position in neonates receiving mechanical ventilation',
#  'Lung volume reduction surgery for diffuse emphysema',
#  'Cognitive rehabilitation for memory deficits following stroke',
#  'Vitamin A supplementation to prevent mortality and short and long-term morbidity in very low birthweight infants',
#  "WITHDRAWN: Anti-tuberculous therapy for maintenance of remission in Crohn's disease",
#  'Interventions to improve water, sanitation, and hygiene for preventing soil-transmitted helminth infection',
#  'Prophylactic nasal continuous positive airways pressure for preventing morbidity and mortality in very preterm infants',
#  'Artichoke leaf extract for treating hypercholesterolaemia',
#  'Gauze and tape and transparent polyurethane dressings for central venous catheters',
#  'WITHDRAWN: Antiplatelet agents versus control or anticoagulation for heart failure in sinus rhythm',
#  'Alpha2 adrenergic agonists for the management of opioid withdrawal',
#  'Phenytoin versus valproate monotherapy for partial onset seizures and generalised onset tonic-clonic seizures: an individual participant data review',
#  'Topical steroid for chronic rhinosinusitis without polyps',
#  'Immunotherapy for advanced renal cell cancer',
#  'Pharmacological interventions for promoting smoking cessation during pregnancy',
#  'Chest physiotherapy compared to no chest physiotherapy for cystic fibrosis',
#  'Interventions for replacing missing teeth: preprosthetic surgery versus dental implants',
#  'Addition of long-acting beta-agonists to inhaled corticosteroids for chronic asthma in children',
#  'Comparison of different platelet count thresholds to guide administration of prophylactic platelet transfusion for preventing bleeding in patients with haematological disorders after chemotherapy or stem cell transplantation',
#  'S-adenosyl-L-methionine for alcoholic liver diseases',
#  'Intravesical bacillus Calmette-Guerin versus mitomycin C for Ta and T1 bladder cancer',
#  'Intraarticular corticosteroid for treatment of osteoarthritis of the knee',
#  'Antibiotics for acute maxillary sinusitis in adults',
#  'Lactational amenorrhea for family planning',
#  'Branched-chain amino acids for hepatic encephalopathy',
#  'Macrolides for chronic asthma',
#  'Mucolytic agents for chronic bronchitis or chronic obstructive pulmonary disease',
#  'Immediate post-partum insertion of intrauterine devices',
#  'Drugs versus placebo for dysthymia',
#  'Regional (spinal, epidural, caudal) versus general anaesthesia in preterm infants undergoing inguinal herniorrhaphy in early infancy',
#  'Surgery for small asymptomatic abdominal aortic aneurysms',
#  'Progesterone/progestogen releasing intrauterine systems versus either placebo or any other medication for heavy menstrual bleeding',
#  'Balneotherapy for rheumatoid arthritis',
#  'Psychological therapies (remotely delivered) for the management of chronic and recurrent pain in children and adolescents',
#  'Elective high frequency oscillatory ventilation versus conventional ventilation for acute pulmonary dysfunction in preterm infants',
#  'Steroids, radiotherapy, chemotherapy and stents for superior vena caval obstruction in carcinoma of the bronchus',
#  'Different doses of prophylactic platelet transfusion for preventing bleeding in patients with haematological disorders after chemotherapy or stem cell transplantation',
#  'A therapeutic-only versus prophylactic platelet transfusion strategy for preventing bleeding in patients with haematological disorders after chemotherapy or stem cell transplantation',
#  'Ibuprofen for the treatment of patent ductus arteriosus in preterm and/or low birth weight infants',
#  'WITHDRAWN: Homoeopathic Oscillococcinum for preventing and treating influenza and influenza-like syndromes',
#  'Patient education for preventing diabetic foot ulceration',
#  'Calcimimetics for secondary hyperparathyroidism in chronic kidney disease patients',
#  'Tonsillectomy versus non-surgical treatment for chronic / recurrent acute tonsillitis',
#  'Different classes of antibiotics given to women routinely for preventing infection at caesarean section',
#  'Oral calorie supplements for cystic fibrosis',
#  'Interventions for asymptomatic retinal breaks and lattice degeneration for preventing retinal detachment',
#  'Amphotericin B lipid soluble formulations vs amphotericin B in cancer patients with neutropenia',
#  'Telerehabilitation for people with low vision',
#  'Closure versus non-closure of the peritoneum at caesarean section',
#  'Immediate postabortal insertion of intrauterine devices',
#  'Pulp treatment for extensive decay in primary teeth',
#  'Thrombolysis for acute ischaemic stroke',
#  'Drug therapies for reducing gastric acidity in people with cystic fibrosis',
#  'Laser therapy for venous leg ulcers',
#  'Fluid and pharmacological agents for adhesion prevention after gynaecological surgery',
#  'Ambulatory oxygen for chronic obstructive pulmonary disease',
#  'Bronchodilators for bronchiolitis',
#  'Exercise for osteoarthritis of the hip',
#  'Physiotherapy treatment approaches for the recovery of postural control and lower limb function following stroke',
#  "Family and carer smoking control programmes for reducing children's exposure to environmental tobacco smoke",
#  'Vaccines for preventing influenza in healthy adults',
#  'Post-operative 5-Fluorouracil for glaucoma surgery',
#  'Pharmacological interventions for recurrent abdominal pain (RAP) and irritable bowel syndrome (IBS) in childhood',
#  'Antihypertensive drug therapy for mild to moderate hypertension during pregnancy',
#  'Continuous passive motion following total knee arthroplasty',
#  'Interventions for the treatment of twin-twin transfusion syndrome',
#  'Acupuncture and related interventions for smoking cessation',
#  'Interventions for female drug-using offenders',
#  'Interventions for drug-using offenders with co-occurring mental illness',
#  'Pharmacological interventions for drug-using offenders',
#  'Prophylactic antibiotic therapy for chronic bronchitis',
#  'Chemotherapy versus best supportive care for extensive small cell lung cancer',
#  'Epidural blood patching for preventing and treating post-dural puncture headache',
#  'Comparative efficacy of epidural, subarachnoid, and intracerebroventricular opioids in patients with pain due to cancer',
#  'Hydromorphone for acute and chronic pain',
#  "Mindfulness-based 'third wave' cognitive and behavioural therapies versus treatment as usual for depression",
#  'Sumatriptan plus naproxen for acute migraine headaches in adults',
#  'Behavioural therapies versus other psychological therapies for depression',
#  'D-Penicillamine for preventing retinopathy of prematurity in preterm infants',
#  'Combined inhaled anticholinergics and beta2-agonists for initial treatment of acute asthma in children',
#  'WITHDRAWN: Antibiotics for preventing pneumonia in children with measles',
#  'Enemas during labor',
#  'Interventions for tobacco use cessation in people in treatment for or recovery from substance abuse',
#  'Intravenous immunoglobulin for preventing infection in preterm and/or low-birth-weight infants',
#  'Cognitive rehabilitation for spatial neglect following stroke',
#  'Interventions for treating cholestasis in pregnancy',
#  'Screening for lung cancer',
#  'Surgery versus thrombolysis for initial management of acute limb ischaemia',
#  "Cognitive rehabilitation and cognitive training for early-stage Alzheimer's disease and vascular dementia",
#  'Treatment of infantile spasms',
#  'Increased consumption of fruit and vegetables for the primary prevention of cardiovascular diseases',
#  'Non-steroidal anti-inflammatory drugs (NSAIDs) for treating lateral elbow pain in adults',
#  'Delayed introduction of progressive enteral feeds to prevent necrotising enterocolitis in very low birth weight infants',
#  'Fetal electrocardiogram (ECG) for fetal monitoring during labour',
#  'Thromboprophylaxis for trauma patients',
#  'Rapid versus slow rate of advancement of feedings for promoting growth and preventing necrotizing enterocolitis in parenterally fed low-birth-weight infants',
#  'School-based physical activity programs for promoting physical activity and fitness in children and adolescents aged 6 to 18',
#  'Cooling for newborns with hypoxic ischaemic encephalopathy',
#  'Depot versus daily administration of gonadotrophin releasing hormone agonist protocols for pituitary desensitization in assisted reproduction cycles',
#  'Pressure relieving interventions for preventing and treating diabetic foot ulcers',
#  'Skin grafting for venous leg ulcers',
#  'Vaccines for preventing pneumococcal infection in adults',
#  'Enteral tube feeding for cystic fibrosis',
#  'Ursodeoxycholic acid for primary biliary cirrhosis',
#  'Interventions for treating proximal humeral fractures in adults',
#  'Benzodiazepines for schizophrenia',
#  'Information provision for stroke patients and their caregivers',
#  'Combined spinal-epidural versus epidural analgesia in labour',
#  'Methenamine hippurate for preventing urinary tract infections',
#  'Vitamin K antagonists or low-molecular-weight heparin for the long term treatment of symptomatic venous thromboembolism',
#  'Minocycline for acne vulgaris: efficacy and safety',
#  'Education for contraceptive use by women after childbirth',
#  'Cleavage stage versus blastocyst stage embryo transfer in assisted conception',
#  'Biofeedback and/or sphincter exercises for the treatment of faecal incontinence in adults',
#  'Removal of nail polish and finger rings to prevent surgical infection',
#  'In vitro fertilisation for unexplained subfertility',
#  'Late (≥ 7 days) inhalation corticosteroids to reduce bronchopulmonary dysplasia in preterm infants',
#  'Transfusion thresholds and other strategies for guiding allogeneic red blood cell transfusion',
#  'Urinary diversion and bladder reconstruction/replacement using intestinal segments for intractable incontinence or following cystectomy',
#  'Surgical decompression for cerebral oedema in acute ischaemic stroke',
#  'Urodynamic studies for management of urinary incontinence in children and adults',
#  'Antibiotic prophylaxis regimens and drugs for cesarean section',
#  'Selenium supplementation for the primary prevention of cardiovascular disease',
#  'Fibrates for primary prevention of cardiovascular disease events',
#  'Macrolide antibiotics for cystic fibrosis',
#  'Duration of treatment for asymptomatic bacteriuria during pregnancy',
#  'Teaching critical appraisal skills in health care settings',
#  'Cot-nursing versus incubator care for preterm infants',
#  'WITHDRAWN: Reduced dietary salt for the prevention of cardiovascular disease',
#  'Antiretrovirals for reducing the risk of mother-to-child transmission of HIV infection',
#  'Interventions for preventing lower limb soft-tissue injuries in runners',
#  'Repeat doses of prenatal corticosteroids for women at risk of preterm birth for preventing neonatal respiratory disease',
#  'Antithrombotic agents for preventing thrombosis after infrainguinal arterial bypass surgery',
#  'Heated, humidified air for the common cold',
#  'Umbilical vein injection for management of retained placenta',
#  'Assertive community treatment for people with severe mental disorders',
#  'Coasting (withholding gonadotrophins) for preventing ovarian hyperstimulation syndrome',
#  'Psychological interventions for non-ulcer dyspepsia',
#  'Parenteral anticoagulation in ambulatory patients with cancer',
#  'Single or double-level anterior interbody fusion techniques for cervical degenerative disc disease',
#  'Social skills programmes for schizophrenia',
#  'Family intervention for schizophrenia',
#  'Sedatives for opiate withdrawal in newborn infants',
#  'Hypnotherapy for smoking cessation',
#  'Immunomodulatory agents for idiopathic pulmonary fibrosis',
#  'Short course antibiotics for acute otitis media',
#  'Sympathectomy for neuropathic pain',
#  'Expanding the roles of outpatient pharmacists: effects on health services utilisation, costs, and patient outcomes',
#  "Azathioprine or 6-mercaptopurine for induction of remission in Crohn's disease",
#  'Therapy with glatiramer acetate for multiple sclerosis',
#  'Antibiotic therapy for prophylaxis against infection of pancreatic necrosis in acute pancreatitis',
#  'Graft type for femoro-popliteal bypass surgery',
#  'Speech and language therapy for aphasia following stroke',
#  'Topical agents or dressings for pain in venous leg ulcers',
#  'Bile acids for liver-transplanted patients',
#  'WITHDRAWN: Drugs for treating neurocysticercosis (tapeworm infection of the brain)',
#  'Routine intracranial pressure monitoring in acute coma',
#  'Scapular fixation in muscular dystrophy',
#  'Therapeutic ultrasound for osteoarthritis of the knee',
#  'Enteral versus parenteral nutrition for acute pancreatitis',
#  'Early (< 8 days) systemic postnatal corticosteroids for prevention of bronchopulmonary dysplasia in preterm infants',
#  'Clomiphene citrate for unexplained subfertility in women',
#  'Supported employment for adults with severe mental illness',
#  'Zolmitriptan for acute migraine headaches in adults',
#  'The impact of contracting out on health outcomes and use of health services in low and middle-income countries',
#  'Day hospital versus out-patient care for psychiatric disorders',
#  'Screening for breast cancer with mammography',
#  "Antiviral treatment for Bell's palsy (idiopathic facial paralysis)",
#  'Antenatal day care units versus hospital admission for women with complicated pregnancy',
#  'Oral contraceptive pill for heavy menstrual bleeding',
#  'Insulin-sensitising drugs (metformin, rosiglitazone, pioglitazone, D-chiro-inositol) for women with polycystic ovary syndrome, oligo amenorrhoea and subfertility',
#  'Mifepristone for induction of labour',
#  'Chlorpromazine dose for people with schizophrenia',
#  'Serenoa repens for benign prostatic hyperplasia',
#  'Interventions for educating children who have attended the emergency room for asthma',
#  'Hypothermia for traumatic head injury',
#  'Interventions for replacing missing teeth: different times for loading dental implants',
#  'Treatment for amphetamine psychosis',
#  'Nursing record systems: effects on nursing practice and health care outcomes',
#  'Newborn screening for cystic fibrosis',
#  'Neoadjuvant and adjuvant therapy for operable hepatocellular carcinoma',
#  'Admission avoidance hospital at home',
#  'Inhaled fluticasone at different doses for chronic asthma in adults and children',
#  'Oestrogens and progestogens for preventing and treating postnatal depression',
#  'Vaccines for preventing infection with Pseudomonas aeruginosa in people with cystic fibrosis',
#  "St John's wort for depression",
#  'Surgery for primary supratentorial intracerebral haemorrhage',
#  'Chemotherapeutic wafers for High Grade Glioma',
#  'Tacrolimus (FK506) for induction of remission in refractory ulcerative colitis',
#  'Low-molecular-weight heparins or heparinoids versus standard unfractionated heparin for acute ischaemic stroke',
#  'Adjuvant treatment of anaplastic oligodendrogliomas and oligoastrocytomas',
#  'Intermittent pneumatic compression for treating venous leg ulcers',
#  'WITHDRAWN: Lumbar supports for prevention and treatment of low-back pain',
#  'House dust mite control measures for asthma',
#  'Corticosteroids for the prevention and treatment of post-extubation stridor in neonates, children and adults',
#  'Life skills programmes for chronic mental illnesses',
#  'Skin patch and vaginal ring versus combined oral contraceptives for contraception',
#  'Hormone replacement therapy for cognitive function in postmenopausal women',
#  'Dietary interventions for recurrent abdominal pain (RAP) and irritable bowel syndrome (IBS) in childhood',
#  'Physiotherapy interventions for ankylosing spondylitis',
#  'Psychosocial interventions for people with both severe mental illness and substance misuse',
#  'Cyclical progestogens for heavy menstrual bleeding',
#  'Biophysical profile for fetal assessment in high risk pregnancies',
#  'Combined corticosteroid and long-acting beta-agonist in one inhaler versus long-acting beta-agonists for chronic obstructive pulmonary disease',
#  'Oral morphine for cancer pain',
#  'Oral versus intra-vaginal imidazole and triazole anti-fungal treatment of uncomplicated vulvovaginal candidiasis (thrush)',
#  'Recombinant human insulin-like growth factor I (rhIGF-I) for amyotrophic lateral sclerosis/motor neuron disease',
#  'Hands/knees posture in late pregnancy or labour for fetal malposition (lateral or posterior)',
#  'Colloids versus crystalloids for fluid resuscitation in critically ill patients',
#  'Percutaneous transluminal angioplasty and stenting for carotid artery stenosis',
#  'Pharmaceutical policies: effects of financial incentives for prescribers',
#  'Angiotensin converting enzyme inhibitors in normotensive diabetic patients with microalbuminuria',
#  'SSRIs versus other antidepressants for depressive disorder',
#  'WITHDRAWN: Injection therapy for subacute and chronic benign low-back pain',
#  'Modern combined oral contraceptives for pain associated with endometriosis',
#  'Vitamin C for preventing and treating the common cold',
#  'Timed intercourse versus intra-uterine insemination with or without ovarian hyperstimulation for subfertility in men',
#  'Interventions for treating scabies',
#  'Routine hospital admission versus out-patient or home care in children at diagnosis of type 1 diabetes mellitus',
#  'Ginkgo biloba for cognitive impairment and dementia',
#  'Absorbent products for the containment of urinary and/or faecal incontinence in adults',
#  'Treatments for non-epileptic attack disorder',
#  'Treatment for primary postpartum haemorrhage',
#  'Cyclophosphamide for multiple sclerosis',
#  'Neuraminidase inhibitors for preventing and treating influenza in children',
#  'Molindone for schizophrenia and severe mental illness',
#  'Dietary advice with or without oral nutritional supplements for disease-related malnutrition in adults',
#  'Antibiotics for treating bacterial vaginosis in pregnancy',
#  'Autoinflation for hearing loss associated with otitis media with effusion',
#  'Bisphosphonates for advanced prostate cancer',
#  'Home-based chemically-induced whitening of teeth in adults',
#  'Early intervention for psychosis',
#  'Noradrenergic agonists for acute traumatic brain injury',
#  'Non surgical therapy for anal fissure',
#  'Opioid antagonists for smoking cessation',
#  'Opioids for neuropathic pain',
#  'Screening programmes for the early detection and prevention of oral cancer',
#  'Biphasic versus triphasic oral contraceptives for contraception',
#  'Local treatments for cutaneous warts',
#  'Neuraminidase inhibitors for preventing and treating influenza in healthy adults',
#  'Pharmaceutical policies: effects of reference pricing, other pricing, and purchasing policies',
#  'Strategies for integrating primary health services in middle- and low-income countries at the point of delivery',
#  'Hyaluronidase for cervical priming and induction of labour',
#  'Intravenous immunoglobulin for myasthenia gravis',
#  'Developmental care for promoting development and preventing morbidity in preterm infants',
#  'Pharmacological interventions for people with borderline personality disorder',
#  'Ibuprofen for the prevention of patent ductus arteriosus in preterm and/or low birth weight infants',
#  'Cotrimoxazole prophylaxis for opportunistic infections in children with HIV infection',
#  'Assisted hatching on assisted conception (IVF and ICSI)',
#  'Echinacea for preventing and treating the common cold',
#  'Combination of inhaled long-acting beta2-agonists and inhaled steroids versus higher dose of inhaled steroids in children and adults with persistent asthma',
#  'Acupuncture for schizophrenia',
#  'Interactive Health Communication Applications for people with chronic disease',
#  'Vitamin A supplementation for reducing the risk of mother-to-child transmission of HIV infection',
#  'Shock wave therapy for lateral elbow pain',
#  'Psychological treatments for epilepsy',
#  'Surgery for obstructive sleep apnoea',
#  'Tailored interventions to overcome identified barriers to change: effects on professional practice and health care outcomes',
#  'Frequency of administration of recombinant human erythropoietin for anaemia of end-stage renal disease in dialysis patients',
#  'Surgical sealant for preventing air leaks after pulmonary resections in patients with lung cancer',
#  'Transcutaneous electrical nerve stimulation (TENS) for chronic low-back pain',
#  'Interventions for preoperative smoking cessation',
#  'Interventions for preventing obesity in children',
#  'Traditional suburethral sling operations for urinary incontinence in women',
#  'Sertindole for schizophrenia',
#  'Laparoscopic "drilling" by diathermy or laser for ovulation induction in anovulatory polycystic ovary syndrome',
#  'Exercise therapy for low back pain',
#  'Heroin maintenance for chronic heroin dependents',
#  'Glucosamine therapy for treating osteoarthritis',
#  'Operative procedures for fissure in ano',
#  'Reminiscence therapy for dementia',
#  'Behavioural treatment for chronic low-back pain',
#  'Membrane sweeping for induction of labour',
#  'Depot fluphenazine decanoate and enanthate for schizophrenia',
#  'NSAIDS or paracetamol, alone or combined with opioids, for cancer pain',
#  'Cytotoxic drugs and interferons for chronic inflammatory demyelinating polyradiculoneuropathy',
#  'WITHDRAWN: Extended versus limited lymph nodes dissection technique for adenocarcinoma of the stomach',
#  'Interventions for improving mobility after hip fracture surgery in adults',
#  'Cognitive behaviour therapy for schizophrenia',
#  'Anaesthesia for hip fracture surgery in adults',
#  'Circulatory volume expansion for aneurysmal subarachnoid hemorrhage',
#  'Ribavirin for respiratory syncytial virus infection of the lower respiratory tract',
#  'Progestogens in combined oral contraceptives for contraception',
#  'Common antiepileptic drugs in pregnancy in women with epilepsy',
#  'Topical umbilical cord care at birth',
#  'Hormone replacement therapy in postmenopausal women: endometrial hyperplasia and irregular bleeding',
#  'Addition of anti-leukotriene agents to inhaled corticosteroids for chronic asthma',
#  'Radiofrequency thermal ablation versus other interventions for hepatocellular carcinoma',
#  'Anti-leukotriene agents compared to inhaled corticosteroids in the management of recurrent and/or chronic asthma in adults and children',
#  'Intra-pleural fibrinolytic therapy vs. conservative management in the treatment of parapneumonic effusions and empyema',
#  'Inhaled fluticasone versus inhaled beclomethasone or inhaled budesonide for chronic asthma in adults and children',
#  'Arthroplasties (with and without bone cement) for proximal femoral fractures in adults',
#  'Population-based interventions for reducing sexually transmitted infections, including HIV infection',
#  'Quetiapine for schizophrenia',
#  'Local versus general anaesthesia for carotid endarterectomy',
#  'Immersion in water in pregnancy, labour and birth',
#  'Perioperative fluid volume optimization following proximal femoral fracture',
#  'Feverfew for preventing migraine',
#  'Pneumococcal vaccines for preventing otitis media',
#  'Breathing exercises for adults with asthma',
#  'Topical emollient for preventing infection in preterm infants',
#  'Gamma and other cephalocondylic intramedullary nails versus extramedullary implants for extracapsular hip fractures in adults',
#  'Folic acid with or without vitamin B12 for cognition and dementia',
#  'Compression therapy for treating stage I and II (Widmer) post-thrombotic syndrome',
#  'Depot risperidone for schizophrenia',
#  'Immunosuppressive agents for treating IgA nephropathy',
#  'Inspiratory muscle training for asthma',
#  'Nutritional interventions for preventing and treating pressure ulcers',
#  'Vitamin B12 for cognition',
#  'Antibiotics to prevent complications following dental implant treatment',
#  'Lithium for schizophrenia',
#  'Methadone at tapered doses for the management of opioid withdrawal',
#  'Treatments for gestational diabetes and impaired glucose tolerance in pregnancy',
#  'Male circumcision for prevention of heterosexual acquisition of HIV in men',
#  'Treatment of Lennox-Gastaut syndrome',
#  "Treatment of Kaposi's sarcoma in HIV-1 infected individuals with emphasis on resource poor settings",
#  'Amniocentesis and chorionic villus sampling for prenatal diagnosis',
#  'Aromatherapy for dementia',
#  'Colony stimulating factors for chemotherapy induced febrile neutropenia',
#  'Ethosuximide, sodium valproate or lamotrigine for absence seizures in children and adolescents',
#  'Inhaled sodium cromoglycate for asthma in children',
#  'Interventions for treating obesity in children',
#  'Surgical versus non-surgical treatment for carpal tunnel syndrome',
#  'Hip protectors for preventing hip fractures in older people',
#  'Periurethral injection therapy for urinary incontinence in women',
#  'Antidepressants for generalized anxiety disorder',
#  'Kangaroo mother care to reduce morbidity and mortality in low birthweight infants',
#  'Low level laser therapy (Classes I, II and III) for treating osteoarthritis',
#  'Naltrexone maintenance treatment for opioid dependence',
#  'Intra-cytoplasmic sperm injection versus conventional techniques for oocyte insemination during in vitro fertilisation in patients with non-male subfertility',
#  'Antibiotics for preterm rupture of membranes',
#  'Miscellaneous treatments for neuroleptic-induced tardive dyskinesia',
#  'Effects of low sodium diet versus high sodium diet on blood pressure, renin, aldosterone, catecholamines, cholesterols, and triglyceride',
#  'Haemoglobin and haematocrit targets for the anaemia of chronic renal disease',
#  'Occlusal adjustment for treating and preventing temporomandibular joint disorders',
#  "Elective delivery of women with a twin pregnancy from 37 weeks' gestation",
#  'Self-management education for chronic obstructive pulmonary disease',
#  'Work conditioning, work hardening and functional restoration for workers with back and neck pain',
#  'Corticosteroid therapy for nephrotic syndrome in children',
#  'Interferon for interferon nonresponding and relapsing patients with chronic hepatitis C',
#  'Debridement of diabetic foot ulcers',
#  'Intravascular brachytherapy for peripheral vascular disease',
#  'Interventions for relieving the pain and discomfort of screening mammography',
#  'Antibiotic prophylaxis during the second and third trimester to reduce adverse pregnancy outcomes and morbidity',
#  'Oral or topical nasal steroids for hearing loss associated with otitis media with effusion in children',
#  'Drug management for acute tonic-clonic convulsions including convulsive status epilepticus in children',
#  'Laparoscopic surgery for subfertility associated with endometriosis',
#  'School-based programmes for preventing smoking',
#  'Interventions for treating tuberculous pericarditis',
#  'Vaginal disinfection during labour for reducing the risk of mother-to-child transmission of HIV infection',
#  'Interventions for replacing missing teeth: hyperbaric oxygen therapy for irradiated patients who require dental implants',
#  'Double gloving to reduce surgical cross-infection',
#  'Early postnatal discharge from hospital for healthy mothers and term infants',
#  'Techniques for preventing hypotension during spinal anaesthesia for caesarean section',
#  'Interventions in the management of serum lipids for preventing stroke recurrence',
#  'Antibiotics for prelabour rupture of membranes at or near term',
#  'Antibiotic duration for treating uncomplicated, symptomatic lower urinary tract infections in elderly women',
#  'Pre-operative endometrial thinning agents before endometrial destruction for heavy menstrual bleeding',
#  'Long-acting beta2-agonists for chronic obstructive pulmonary disease patients with poorly reversible airflow limitation',
#  'Prostaglandins for prevention of postpartum haemorrhage',
#  'Cardioselective beta-blockers for chronic obstructive pulmonary disease',
#  'Humidity control for chronic asthma',
#  'Drug treatments for obstructive sleep apnoea',
#  'Early versus delayed initiation of continuous distending pressure for respiratory distress syndrome in preterm infants',
#  'Opioid antagonists under heavy sedation or anaesthesia for opioid withdrawal',
#  'Massage for low-back pain',
#  'Posture and fluids for preventing post-dural puncture headache',
#  'Oral naltrexone maintenance treatment for opioid dependence',
#  'Antioxidant vitamin and mineral supplements for slowing the progression of age-related macular degeneration',
#  'Aerobic exercise for women during pregnancy',
#  'Interventions for enhancing medication adherence',
#  'Inhaled hyperosmolar agents for bronchiectasis',
#  'Antibiotics versus control for toxoplasma retinochoroiditis',
#  "WITHDRAWN: Corticosteroids for Bell's palsy (idiopathic facial paralysis)",
#  'Nutritional supplementation for stable chronic obstructive pulmonary disease',
#  'Breast stimulation for cervical ripening and induction of labour',
#  'Conservative treatments for whiplash',
#  'Anticoagulation for heart failure in sinus rhythm',
#  'Treatment for amphetamine dependence and abuse',
#  'Benzodiazepine receptor antagonists for acute and chronic hepatic encephalopathy',
#  'Phenobarbitone versus phenytoin monotherapy for partial onset seizures and generalised onset tonic-clonic seizures',
#  'Interventions for treating oral leukoplakia',
#  'Gonadotrophin-releasing hormone antagonists for assisted conception',
#  'House dust mite avoidance measures for perennial allergic rhinitis',
#  'Oral anticoagulants versus antiplatelet therapy for preventing further vascular events after transient ischaemic attack or minor stroke of presumed arterial origin',
#  'Laparoscopic surgery for pelvic pain associated with endometriosis',
#  'Patterns of routine antenatal care for low-risk pregnancy',
#  'Dietary salt reduction or exclusion for allergic asthma',
#  'Fish oil in people with type 2 diabetes mellitus',
#  'Valproic acid, valproate and divalproex in the maintenance treatment of bipolar disorder',
#  "Physiotherapy for patients with Parkinson's Disease: a comparison of techniques",
#  'Zuclopenthixol acetate in the treatment of acute schizophrenia and similar serious mental illnesses',
#  'Tracheal suctioning without disconnection in intubated ventilated neonates',
#  'Radical radiotherapy for stage I/II non-small cell lung cancer in patients not sufficiently fit for or declining surgery (medically inoperable)',
#  'Droperidol for acute psychosis',
#  'Intravenous immunoglobulin for Guillain-Barré syndrome',
#  'Antidepressant drug treatment for postnatal depression',
#  'Erythromycin for feeding intolerance in preterm infants',
#  'Iron therapy for improving psychomotor development and cognitive function in children under the age of three with iron deficiency anaemia',
#  'Prophylactic versus selective use of surfactant in preventing morbidity and mortality in preterm infants',
#  'Electromagnetic therapy for treating venous leg ulcers',
#  'Topical negative pressure for treating chronic wounds',
#  'Routine perineal shaving on admission in labour',
#  'Tamoxifen for relapse of ovarian cancer',
#  'Vitamin D and vitamin D analogues for preventing fractures associated with involutional and post-menopausal osteoporosis',
#  'Angiotensin receptor blockers for heart failure',
#  'Transcutaneous electrical nerve stimulation for knee osteoarthritis',
#  'Therapeutic ultrasound for venous leg ulcers',
#  'Discharge planning from hospital to home',
#  'Antibiotics for acute bronchitis',
#  'Antibiotics for acute otitis media in children',
#  'Exercise interventions for smoking cessation',
#  'Cyclophosphamide versus methylprednisolone for treating neuropsychiatric involvement in systemic lupus erythematosus',
#  'Surgery for degenerative lumbar spondylosis',
#  'On-site mental health workers in primary care: effects on professional practice',
#  'Progestagens and anti-progestagens for pain associated with endometriosis',
#  'Hyperbaric oxygen for carbon monoxide poisoning',
#  'Radiotherapy for the palliation of painful bone metastases',
#  'Interventions for tubal ectopic pregnancy',
#  'Cervical insemination versus intra-uterine insemination of donor sperm for subfertility',
#  'Techniques for pelvic surgery in subfertility',
#  'Corticosteroids for acute traumatic brain injury',
#  'Antipyretic measures for treating fever in malaria',
#  'Telemedicine versus face to face patient care: effects on professional practice and health care outcomes',
#  'Patient held clinical information for people with psychotic illnesses',
#  'Zinc for the common cold',
#  'Treatment and prevention of pouchitis after ileal pouch-anal anastomosis for chronic ulcerative colitis',
#  'Mass media interventions for preventing smoking in young people',
#  'Vaccines for preventing tick-borne encephalitis',
#  'Local opinion leaders: effects on professional practice and health care outcomes',
#  'Interprofessional collaboration: effects of practice-based interventions on professional practice and healthcare outcomes',
#  'Danazol for unexplained infertilty',
#  'Acupuncture for low back pain',
#  'Interventions for treating hallux valgus (abductovalgus) and bunions',
#  'Lidocaine-prilocaine cream for analgesia during circumcision in newborn boys',
#  'Long-chain polyunsaturated fatty acid supplementation in preterm infants',
#  'Multi-nutrient fortification of human milk for preterm infants',
#  'Non-aspirin, non-steroidal anti-inflammatory drugs for osteoarthritis of the knee',
#  'Early administration of inhaled corticosteroids for preventing chronic lung disease in ventilated very low birth weight preterm neonates',
#  'Induction of labour for suspected fetal macrosomia',
#  'Fat supplementation of human milk for promoting growth in preterm infants',
#  'External cephalic version for breech presentation before term',
#  'Anti-D administration in pregnancy for preventing Rhesus alloimmunisation']

# %%
import time

def count_ngram(query):
    payload = {
        'index': 'v4_dolma-v1_7_llama',
        'query_type': 'count',
        'query': query,
    }
    result = requests.post('https://api.infini-gram.io/', json=payload).json()
    #print(result) #CHANGED
    return result

json_results = list()

for title in changed_titles:
    json_results.append(count_ngram(title))
    time.sleep(0.5)
json_results


cleaned_titles = np.array(titles)
cleaned_titles = [c[:-1] for c in cleaned_titles]
cleaned_titles = [c.replace("?", "") for c in cleaned_titles]
cleaned_titles = [c.replace("  ", " ") for c in cleaned_titles]
cleaned_titles = [c.replace("   ", " ") for c in cleaned_titles]
cleaned_titles
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 16
#      13 json_results = list()
#      15 for title in changed_titles:
# ---> 16     json_results.append(count_ngram(title))
#      17     time.sleep(0.5)
#      18 json_results
#
# Cell In[24], line 9, in count_ngram(query)
#       3 def count_ngram(query):
#       4     payload = {
#       5         'index': 'v4_dolma-v1_7_llama',
#       6         'query_type': 'count',
#       7         'query': query,
#       8     }
# ----> 9     result = requests.post('https://api.infini-gram.io/', json=payload).json()
#      10     #print(result) #CHANGED
#      11     return result
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\mespi\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import time

def count_ngram(query):
    payload = {
        'index': 'v4_dolma-v1_7_llama',
        'query_type': 'count',
        'query': query,
    }
    result = requests.post('https://api.infini-gram.io/', json=payload).json()
    print(result)
    return result

full_json_results = list()

for title in cleaned_titles:
    full_json_results.append(count_ngram(title))
    time.sleep(0.8)


c = 0
counts = list()
for js in full_json_results:
    try:
        counts.append(js["count"])
    except:
        counts.append(0)
        c+=1
print(c)
counts = np.array(counts)
len(counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 15
#      11     return result
#      13 full_json_results = list()
# ---> 15 for title in cleaned_titles:
#      16     full_json_results.append(count_ngram(title))
#      17     time.sleep(0.8)
#
# NameError: name 'cleaned_titles' is not defined

# %%
full_latest_ids = [dg[0] for dg in doigroups]
full_latest_ids = sorted(full_latest_ids)
len(full_latest_ids)

years = list()
ids_per_year = dict()
for y in range(2000, 2025):
    ids_per_year[str(y)] = list()

df = pd.read_csv("./FullScraped.csv", index_col=0)
dates = df.date.tolist()
dates = [d.split("Cochrane Database Syst Rev.")[1].strip()[:4] if "Cochrane Database Syst Rev." in d else "" for d in dates]

for fli in full_latest_ids:
    year = dates[fli]
    ids_per_year[year].append(fli)
    years.append(dates[fli])


year_counts = dict(zip(ids_per_year.keys(), [0]*len(ids_per_year.keys())))
year_sums = dict(zip(ids_per_year.keys(), [0]*len(ids_per_year.keys())))

year_countlists = dict()

for year in ids_per_year.keys():
    year_countlists[year] = list()

for idx in range(len(dates)):
    year = dates[idx]
    count = counts[idx]

    year_counts[year] += 1
    year_sums[year] += count

    year_countlists[year].append(count)

year_countlists


for key, value in year_sums.items():
    print(key, value/year_counts[key])
    print(key, np.median(np.array(year_countlists[key])))
    print("  ")

# %%
import matplotlib.pyplot as plt
import numpy as np

''' Plot the n-gram counts over the years '''

# Data provided
data = [
    (2000, 42.111000991080275, 20.0),
    (2001, 52.63333333333333, 23.0),
    (2002, 47.3978021978022, 27.0),
    (2003, 48.988188976377955, 28.0),
    (2004, 54.72140221402214, 28.0),
    (2005, 44.83970856102004, 28.0),
    (2006, 54.95674740484429, 30.0),
    (2007, 37.6675567423231, 21.0),
    (2008, 42.50354609929078, 24.0),
    (2009, 39.649532710280376, 22.0),
    (2010, 40.01033591731266, 21.0),
    (2011, 39.78203434610304, 21.0),
    (2012, 39.76604146100691, 22.0),
    (2013, 42.10798122065728, 20.0),
    (2014, 32.301384451544195, 18.0),
    (2015, 28.74308300395257, 16.0),
    (2016, 25.783352337514252, 14.0),
    (2017, 27.019354838709678, 13.0),
    (2018, 22.353204172876303, 11.0),
    (2019, 20.89090909090909, 8.0),
    (2020, 21.214776632302407, 8.0),
    (2021, 17.03731343283582, 4.0),
    (2022, 14.085470085470085, 3.0),
    (2023, 17.06746987951807, 1.0),
    (2024, 32.65217391304348, 0.0)
]

# Separate the data into lists
years = [item[0] for item in data]
count1 = [item[1] for item in data]
count2 = [item[2] for item in data]

# Create the plot
plt.figure(figsize=(5.5, 3.8))  # Adjust figure size for better readability

# Define a color palette suitable for publications
color_palette = ['#0072B2', '#D55E00']  # Blue and Orange - Colorblind friendly

# Plot the two line charts with distinct colors and markers
plt.plot(years, count1, marker='o', linestyle='-', color=color_palette[0], label='Mean Average')
plt.plot(years, count2, marker='s', linestyle='--', color=color_palette[1], label='Median')

# Add labels and title with a more formal style
plt.xlabel('Year of study publication', fontsize=10, fontweight='bold')
plt.ylabel('N-gram count in Dolma', fontsize=10, fontweight='bold')
plt.title('Mentions of SLR titles from different years', fontsize=11, fontweight='bold')

# Add a legend to distinguish the two lines
plt.legend(fontsize=10, loc='upper right')

# Add gridlines for better readability, with a subtle style
plt.grid(True, linestyle=':', alpha=0.7)

# Customize the axes
xtick_labels = [str(year) for year in years] # Start with all years as strings
xtick_labels[-1] = "Jan 2024" # Change the last label

plt.xticks(years, xtick_labels, fontsize=9) # Apply both the positions (years) and the custom labels
plt.yticks(fontsize=10)

# Make the plot look cleaner
plt.gca().spines['top'].set_visible(False)    # Remove top spine
plt.gca().spines['right'].set_visible(False)  # Remove right spine
plt.gca().xaxis.set_tick_params(rotation=40, direction='out')  
plt.gca().yaxis.set_tick_params(direction='out')

# Adjust layout to prevent labels from overlapping
plt.tight_layout()

# Save the plot as a high-resolution TIFF file (for publications)
#plt.savefig('year_vs_counts_plot.tiff', format='tiff', dpi=300)  # 300 dpi is good for print

# Show the plot
plt.show()
